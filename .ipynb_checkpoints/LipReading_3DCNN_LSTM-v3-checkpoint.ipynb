# %%
import tensorflow as tf
from keras.models import model_from_json
import os
import numpy as np
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import imageio
from matplotlib import pyplot as plt
import warnings
import cv2
import pandas as pd
from mtcnn.mtcnn import MTCNN
import keras.backend as K
from keras.layers import MaxPooling3D, SpatialDropout3D, Activation, Input, Dense, Conv3D, MaxPooling2D, UpSampling2D,Lambda, TimeDistributed,Flatten, BatchNormalization
from keras.models import Model
from keras import backend as K
from keras.utils import to_categorical
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
warnings.filterwarnings("ignore")
from keras.callbacks import TensorBoard, CSVLogger, ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
words = [
    'BETWEEN'
,'OPPOSITION'
,'EVERYBODY'
,'GOVERNMENT'
,'THEMSELVES'
,'ABSOLUTELY'
,'SEVERAL'
,'WESTMINSTER'
,'CONFERENCE'
,'AFTERNOON'
,'AGREEMENT'
,'REFERENDUM'
,'FINANCIAL'
,'TEMPERATURES'
,'EXPECTED'
,'IMMIGRATION'
,'INDEPENDENT'
,'SIGNIFICANT'
,'CONSERVATIVE'
,'EMERGENCY'
,'PARLIAMENT'
]
# df = pd.DataFrame()
# df['words']=sorted(words)
# df['id']=list(range(len(words)))
# df.to_csv('words_v2.csv')

# %%
tf_config = tf.ConfigProto(allow_soft_placement=False)
tf_config.gpu_options.allow_growth = True
s = tf.Session(config=tf_config)
K.set_session(s)

# %%
def _ctc_lambda_func(args):
    labels, y_pred, input_length, label_length = args
    y_pred = y_pred[:, :, :]
    return K.tf.keras.backend.ctc_batch_cost(labels, y_pred, input_length, label_length)
with open('LipReading_model.json') as f:
    loadedmodel = f.read()
lm = model_from_json(loadedmodel)
_max3 = lm.get_layer('max3').output
_labels = lm.get_layer('the_labels').output
_y_pred = lm.get_layer('softmax').output
_input_length = lm.get_layer('input_length').output
_label_length = lm.get_layer('label_length').output
# td = TimeDistributed(Dense(32))(_y_pred)
# fl = Conv3D(kernel_size=(1,1,1),filters=128)(_max3)
conv = Conv3D(128, (2, 2, 2), strides=(1, 2, 2), kernel_initializer='he_normal', name='e_conv', padding='same')(_max3)
batch = BatchNormalization(name='e_batch')(conv)
actv = Activation('relu', name='e_actv')(batch)
drop = SpatialDropout3D(0.5)(actv)
_maxp = MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2), name='e_max')(drop)
fl = Flatten()(_maxp)
fl = Dense(2048, activation='relu')(fl)
fl = Dense(1024, activation='relu')(fl)
classification_output=Dense(21,activation='softmax', name='classification')(fl)
ctc_loss = Lambda(_ctc_lambda_func, output_shape=(1,), name='ctc')([_labels,_y_pred,_input_length,_label_length])
model = Model(inputs=lm.input, outputs=[classification_output,ctc_loss])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_input (InputLayer)          (None, 30, 100, 50,  0
# __________________________________________________________________________________________________
# zero1 (ZeroPadding3D)           (None, 32, 104, 54,  0           the_input[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv3D)                  (None, 30, 50, 25, 3 7232        zero1[0][0]
# __________________________________________________________________________________________________
# batc1 (BatchNormalization)      (None, 30, 50, 25, 3 128         conv1[0][0]
# __________________________________________________________________________________________________
# actv1 (Activation)              (None, 30, 50, 25, 3 0           batc1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout3d_19 (SpatialDr (None, 30, 50, 25, 3 0           actv1[0][0]
# __________________________________________________________________________________________________
# max1 (MaxPooling3D)             (None, 30, 25, 12, 3 0           spatial_dropout3d_19[0][0]
# __________________________________________________________________________________________________
# zero2 (ZeroPadding3D)           (None, 32, 29, 16, 3 0           max1[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv3D)                  (None, 30, 25, 12, 6 153664      zero2[0][0]
# __________________________________________________________________________________________________
# batc2 (BatchNormalization)      (None, 30, 25, 12, 6 256         conv2[0][0]
# __________________________________________________________________________________________________
# actv2 (Activation)              (None, 30, 25, 12, 6 0           batc2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout3d_20 (SpatialDr (None, 30, 25, 12, 6 0           actv2[0][0]
# __________________________________________________________________________________________________
# max2 (MaxPooling3D)             (None, 30, 12, 6, 64 0           spatial_dropout3d_20[0][0]
# __________________________________________________________________________________________________
# zero3 (ZeroPadding3D)           (None, 32, 14, 8, 64 0           max2[0][0]
# __________________________________________________________________________________________________
# conv3 (Conv3D)                  (None, 30, 12, 6, 96 165984      zero3[0][0]
# __________________________________________________________________________________________________
# batc3 (BatchNormalization)      (None, 30, 12, 6, 96 384         conv3[0][0]
# __________________________________________________________________________________________________
# actv3 (Activation)              (None, 30, 12, 6, 96 0           batc3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout3d_21 (SpatialDr (None, 30, 12, 6, 96 0           actv3[0][0]
# __________________________________________________________________________________________________
# max3 (MaxPooling3D)             (None, 30, 6, 3, 96) 0           spatial_dropout3d_21[0][0]
# __________________________________________________________________________________________________
# e_conv (Conv3D)                 (None, 30, 3, 2, 128 98432       max3[0][0]
# __________________________________________________________________________________________________
# e_batch (BatchNormalization)    (None, 30, 3, 2, 128 512         e_conv[0][0]
# __________________________________________________________________________________________________
# e_actv (Activation)             (None, 30, 3, 2, 128 0           e_batch[0][0]
# __________________________________________________________________________________________________
# spatial_dropout3d_1 (SpatialDro (None, 30, 3, 2, 128 0           e_actv[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 30, 1728)     0           max3[0][0]
# __________________________________________________________________________________________________
# e_max (MaxPooling3D)            (None, 30, 1, 1, 128 0           spatial_dropout3d_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_13 (Bidirectional (None, 30, 512)      3048960     time_distributed_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 3840)         0           e_max[0][0]
# __________________________________________________________________________________________________
# bidirectional_14 (Bidirectional (None, 30, 512)      1181184     bidirectional_13[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2048)         7866368     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 30, 28)       14364       bidirectional_14[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1024)         2098176     dense_1[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         (None, 12)           0
# __________________________________________________________________________________________________
# softmax (Activation)            (None, 30, 28)       0           dense1[0][0]
# __________________________________________________________________________________________________
# input_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# label_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# classification (Dense)          (None, 21)           21525       dense_2[0][0]
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           the_labels[0][0]
#                                                                  softmax[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 14,657,169
# Trainable params: 14,656,529
# Non-trainable params: 640
# __________________________________________________________________________________________________

# %%
SVG(model_to_dot(model, show_layer_names=True, show_shapes=True).create(prog='dot', format='svg'))

# %%
frames_count = 30
# words_folder = 'training/unseen_speakers/TARGET/datasets/lipread_mp4'
words = pd.read_csv('words_v2.csv')['words']
max_len = np.max([len(word) for word in words])

def datagen(data_partition = 'train', batch_size = 16):
    while True:
        counter = 0
        
        X_data = []#np.zeros((batch_size,))
        Y_data = []
        input_length = []
        label_length = []
        source_str = []
        word_id = []
        while counter<batch_size:
#             print(counter)
            word_idx = np.random.randint(len(words))
#             print('data part:', data_partition, ', word index', word_idx)
            
            train_folder = 'training/unseen_speakers/lrw_cropped/{0}/{1}/'.format(words[word_idx],data_partition)
        #         print(train_folder)
            files = os.listdir(train_folder)
        #         print(files)
            paths = list(set([x.split('.')[0] for x in files]))
        
            idx = np.random.randint(len(paths))
            path = os.path.join(train_folder,paths[idx])
#             print(path)
            frames = []
            for img_name in sorted(os.listdir(path)):
                img = cv2.imread(os.path.join(path,img_name))
                frames.append(img)
            frames = np.array(frames)
#             print(frames.shape, path)
            if len(frames.shape)==4:
#                 frames = np.rollaxis(frames,2, start=1)
    #             print(path)
    #             print(frames.shape)
    #             print('---------')
                if 'numpy.ndarray' in str(type(frames)) \
                        and len(np.shape(frames))==4 \
                        and np.shape(frames)[1] == 100 \
                        and np.shape(frames)[2] == 50:
#                     print(frames.shape, path)
                    if len(frames)<30:
                        diff = 30-len(frames)
            #             print(fr[-1].shape)
                        for i in range(diff):
                            frames = np.insert(arr = frames,values = frames[-1], obj=[-1], axis = 0)
                    X_data.append(frames)
                    ####
                    Y_data.append([ord(c) - 65 for c in words[word_idx]]+[-1]*(max_len-len(words[word_idx])))
                    input_length.append(frames_count)
                    label_length.append(len(words[word_idx]))
                    source_str.append(words[word_idx])
                    word_id.append(word_idx)
                    counter+=1
#                     print(counter)
                else:
                    continue
            else:
                print('error:', frames.shape, path)
                continue

        X_data = np.array(X_data).astype(np.float32) / 255 
        Y_data = np.array(Y_data)
        input_length = np.array(input_length)
        label_length = np.array(label_length)
        source_str = np.array(source_str)
        
        inputs = {'the_input': X_data,
                  'the_labels': Y_data,
                  'input_length': input_length,
                  'label_length': label_length,
                  'source_str': source_str  # used for visualization only
                  }
        ctc_outpts = np.zeros([batch_size])
        classes = to_categorical(y=word_id,num_classes=len(words))   
        
#         print('the_input:', inputs['the_input'].shape)
#         print('the_labels:', inputs['the_labels'].shape)
#         print('input_length:', inputs['input_length'].shape)
#         print('label_length:', inputs['label_length'].shape)
#         print('source_str:', inputs['source_str'].shape)
#         print('batch_frames_shape',X_data.shape, data_partition)

        yield inputs, [classes,ctc_outpts]

# %%
word_idx = np.random.randint(len(words))
#             print('data part:', data_partition, ', word index', word_idx)

train_folder = 'training/unseen_speakers/lrw_cropped/{0}/{1}/'.format(words[word_idx],'train')
#         print(train_folder)

files = os.listdir(train_folder)

paths = list(set([x.split('.')[0] for x in files]))
idx = np.random.randint(len(paths))
path = os.path.join(train_folder,paths[idx])
path = 'training/unseen_speakers/lrw_cropped/FINANCIAL/train/FINANCIAL_00001/'
print(path)
frames = []
for img_name in sorted(os.listdir(path)):
    img = cv2.imread(os.path.join(path,img_name))
    frames.append(img)
frames = np.array(frames)
frames.shape
# Out:
# training/unseen_speakers/lrw_cropped/FINANCIAL/train/FINANCIAL_00001/
# (30, 100, 50, 3)

# %%
g_tr=datagen(data_partition='train',batch_size=64)
g_val=datagen(data_partition='test',batch_size=64)

# %%
x,y=next(g_tr)
display(x['the_input'].shape,x['the_input'].min(),x['the_input'].max(),x['the_labels'],x['input_length'],x['label_length'],x['source_str'])
np.argmax(y[0],axis=1)
# Out:
# (64, 30, 100, 50, 3)
# 0.0
# 1.0
# array([[ 0,  5, 19,  4, 17, 13, 14, 14, 13, -1, -1, -1],
#        [15,  0, 17, 11,  8,  0, 12,  4, 13, 19, -1, -1],
#        [22,  4, 18, 19, 12,  8, 13, 18, 19,  4, 17, -1],
#        [ 8, 12, 12,  8,  6, 17,  0, 19,  8, 14, 13, -1],
#        [ 5,  8, 13,  0, 13,  2,  8,  0, 11, -1, -1, -1],
#        [ 5,  8, 13,  0, 13,  2,  8,  0, 11, -1, -1, -1],
#        [ 2, 14, 13,  5,  4, 17,  4, 13,  2,  4, -1, -1],
#        [22,  4, 18, 19, 12,  8, 13, 18, 19,  4, 17, -1],
#        [ 6, 14, 21,  4, 17, 13, 12,  4, 13, 19, -1, -1],
#        [ 6, 14, 21,  4, 17, 13, 12,  4, 13, 19, -1, -1],
#        [19,  4, 12, 15,  4, 17,  0, 19, 20, 17,  4, 18],
#        [ 6, 14, 21,  4, 17, 13, 12,  4, 13, 19, -1, -1],
#        [ 4, 23, 15,  4,  2, 19,  4,  3, -1, -1, -1, -1],
#        [ 2, 14, 13, 18,  4, 17, 21,  0, 19,  8, 21,  4],
#        [ 6, 14, 21,  4, 17, 13, 12,  4, 13, 19, -1, -1],
#        [18,  4, 21,  4, 17,  0, 11, -1, -1, -1, -1, -1],
#        [ 0,  5, 19,  4, 17, 13, 14, 14, 13, -1, -1, -1],
#        [ 4, 12,  4, 17,  6,  4, 13,  2, 24, -1, -1, -1],
#        [ 0,  6, 17,  4,  4, 12,  4, 13, 19, -1, -1, -1],
#        [ 4, 21,  4, 17, 24,  1, 14,  3, 24, -1, -1, -1],
#        [15,  0, 17, 11,  8,  0, 12,  4, 13, 19, -1, -1],
#        [ 6, 14, 21,  4, 17, 13, 12,  4, 13, 19, -1, -1],
#        [ 1,  4, 19, 22,  4,  4, 13, -1, -1, -1, -1, -1],
#        [ 0,  1, 18, 14, 11, 20, 19,  4, 11, 24, -1, -1],
#        [ 4, 23, 15,  4,  2, 19,  4,  3, -1, -1, -1, -1],
#        [22,  4, 18, 19, 12,  8, 13, 18, 19,  4, 17, -1],
#        [ 8, 13,  3,  4, 15,  4, 13,  3,  4, 13, 19, -1],
#        [ 1,  4, 19, 22,  4,  4, 13, -1, -1, -1, -1, -1],
#        [ 0,  1, 18, 14, 11, 20, 19,  4, 11, 24, -1, -1],
#        [ 0,  1, 18, 14, 11, 20, 19,  4, 11, 24, -1, -1],
#        [ 2, 14, 13, 18,  4, 17, 21,  0, 19,  8, 21,  4],
#        [22,  4, 18, 19, 12,  8, 13, 18, 19,  4, 17, -1],
#        [ 6, 14, 21,  4, 17, 13, 12,  4, 13, 19, -1, -1],
#        [19,  7,  4, 12, 18,  4, 11, 21,  4, 18, -1, -1],
#        [19,  7,  4, 12, 18,  4, 11, 21,  4, 18, -1, -1],
#        [ 8, 13,  3,  4, 15,  4, 13,  3,  4, 13, 19, -1],
#        [ 0,  6, 17,  4,  4, 12,  4, 13, 19, -1, -1, -1],
#        [19,  4, 12, 15,  4, 17,  0, 19, 20, 17,  4, 18],
#        [22,  4, 18, 19, 12,  8, 13, 18, 19,  4, 17, -1],
#        [19,  7,  4, 12, 18,  4, 11, 21,  4, 18, -1, -1],
#        [ 0,  5, 19,  4, 17, 13, 14, 14, 13, -1, -1, -1],
#        [19,  7,  4, 12, 18,  4, 11, 21,  4, 18, -1, -1],
#        [ 8, 12, 12,  8,  6, 17,  0, 19,  8, 14, 13, -1],
#        [ 5,  8, 13,  0, 13,  2,  8,  0, 11, -1, -1, -1],
#        [ 4, 12,  4, 17,  6,  4, 13,  2, 24, -1, -1, -1],
#        [ 8, 13,  3,  4, 15,  4, 13,  3,  4, 13, 19, -1],
#        [ 1,  4, 19, 22,  4,  4, 13, -1, -1, -1, -1, -1],
#        [15,  0, 17, 11,  8,  0, 12,  4, 13, 19, -1, -1],
#        [ 5,  8, 13,  0, 13,  2,  8,  0, 11, -1, -1, -1],
#        [17,  4,  5,  4, 17,  4, 13,  3, 20, 12, -1, -1],
#        [ 6, 14, 21,  4, 17, 13, 12,  4, 13, 19, -1, -1],
#        [ 0,  1, 18, 14, 11, 20, 19,  4, 11, 24, -1, -1],
#        [ 8, 12, 12,  8,  6, 17,  0, 19,  8, 14, 13, -1],
#        [18,  8,  6, 13,  8,  5,  8,  2,  0, 13, 19, -1],
#        [18,  8,  6, 13,  8,  5,  8,  2,  0, 13, 19, -1],
#        [22,  4, 18, 19, 12,  8, 13, 18, 19,  4, 17, -1],
#        [ 6, 14, 21,  4, 17, 13, 12,  4, 13, 19, -1, -1],
#        [ 0,  1, 18, 14, 11, 20, 19,  4, 11, 24, -1, -1],
#        [ 0,  6, 17,  4,  4, 12,  4, 13, 19, -1, -1, -1],
#        [ 0,  5, 19,  4, 17, 13, 14, 14, 13, -1, -1, -1],
#        [ 1,  4, 19, 22,  4,  4, 13, -1, -1, -1, -1, -1],
#        [ 2, 14, 13, 18,  4, 17, 21,  0, 19,  8, 21,  4],
#        [ 1,  4, 19, 22,  4,  4, 13, -1, -1, -1, -1, -1],
#        [ 8, 13,  3,  4, 15,  4, 13,  3,  4, 13, 19, -1]])
# array([30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#        30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#        30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#        30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30])
# array([ 9, 10, 11, 11,  9,  9, 10, 11, 10, 10, 12, 10,  8, 12, 10,  7,  9,
#         9,  9,  9, 10, 10,  7, 10,  8, 11, 11,  7, 10, 10, 12, 11, 10, 10,
#        10, 11,  9, 12, 11, 10,  9, 10, 11,  9,  9, 11,  7, 10,  9, 10, 10,
#        10, 11, 11, 11, 11, 10, 10,  9,  9,  7, 12,  7, 11])
# array(['AFTERNOON', 'PARLIAMENT', 'WESTMINSTER', 'IMMIGRATION',
#        'FINANCIAL', 'FINANCIAL', 'CONFERENCE', 'WESTMINSTER',
#        'GOVERNMENT', 'GOVERNMENT', 'TEMPERATURES', 'GOVERNMENT',
#        'EXPECTED', 'CONSERVATIVE', 'GOVERNMENT', 'SEVERAL', 'AFTERNOON',
#        'EMERGENCY', 'AGREEMENT', 'EVERYBODY', 'PARLIAMENT', 'GOVERNMENT',
#        'BETWEEN', 'ABSOLUTELY', 'EXPECTED', 'WESTMINSTER', 'INDEPENDENT',
#        'BETWEEN', 'ABSOLUTELY', 'ABSOLUTELY', 'CONSERVATIVE',
#        'WESTMINSTER', 'GOVERNMENT', 'THEMSELVES', 'THEMSELVES',
#        'INDEPENDENT', 'AGREEMENT', 'TEMPERATURES', 'WESTMINSTER',
#        'THEMSELVES', 'AFTERNOON', 'THEMSELVES', 'IMMIGRATION',
#        'FINANCIAL', 'EMERGENCY', 'INDEPENDENT', 'BETWEEN', 'PARLIAMENT',
#        'FINANCIAL', 'REFERENDUM', 'GOVERNMENT', 'ABSOLUTELY',
#        'IMMIGRATION', 'SIGNIFICANT', 'SIGNIFICANT', 'WESTMINSTER',
#        'GOVERNMENT', 'ABSOLUTELY', 'AGREEMENT', 'AFTERNOON', 'BETWEEN',
#        'CONSERVATIVE', 'BETWEEN', 'INDEPENDENT'], dtype='<U12')
# array([ 1, 14, 20, 11,  9,  9,  4, 20, 10, 10, 18, 10,  8,  5, 10, 16,  1,
#         6,  2,  7, 14, 10,  3,  0,  8, 20, 12,  3,  0,  0,  5, 20, 10, 19,
#        19, 12,  2, 18, 20, 19,  1, 19, 11,  9,  6, 12,  3, 14,  9, 15, 10,
#         0, 11, 17, 17, 20, 10,  0,  2,  1,  3,  5,  3, 12])

# %%
[(word,len(word)) for word in words]
# Out:
# [('ABSOLUTELY', 10),
#  ('AFTERNOON', 9),
#  ('AGREEMENT', 9),
#  ('BETWEEN', 7),
#  ('CONFERENCE', 10),
#  ('CONSERVATIVE', 12),
#  ('EMERGENCY', 9),
#  ('EVERYBODY', 9),
#  ('EXPECTED', 8),
#  ('FINANCIAL', 9),
#  ('GOVERNMENT', 10),
#  ('IMMIGRATION', 11),
#  ('INDEPENDENT', 11),
#  ('OPPOSITION', 10),
#  ('PARLIAMENT', 10),
#  ('REFERENDUM', 10),
#  ('SEVERAL', 7),
#  ('SIGNIFICANT', 11),
#  ('TEMPERATURES', 12),
#  ('THEMSELVES', 10),
#  ('WESTMINSTER', 11)]

# %%
X = x['the_input'][10]
print()
fig = plt.figure(figsize=(30,30))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
for i in range(30):
    ax = fig.add_subplot(1, 30, i + 1, xticks=[], yticks=[])
    ax.imshow(X[i])

# %%
import datetime
datetime = str(datetime.datetime.now())
LOG_DIR = 'training/unseen_speakers/logs/'
run_name = datetime.replace(' ','_').replace('.','_')
print('run_name:',run_name)
tensorboard = TensorBoard(log_dir=os.path.join(LOG_DIR, run_name))
# csv_logger  = CSVLogger(os.path.join(LOG_DIR, "{}-{}.csv".format('training',run_name)), separator=',', append=True)
checkpoint  = ModelCheckpoint(save_best_only=True,
                              filepath='training/unseen_speakers/results/weights_lfw-crop-ctc_classification-v3.hdf5'
                              , monitor='val_loss'
                              , verbose=1
                              , mode='min'
                              , period=1)
# Out:
# run_name: 2019-03-08_13:51:07_497154

# %%
# def test_loss(y_true, y_pred): 
#     return y_pred

# %%
from keras.optimizers import Adadelta,Adam
adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, decay=1e-08)
# _labels = lm.get_layer('the_labels').output
# _y_pred = lm.get_layer('softmax').output
# _input_length = lm.get_layer('input_length').output
# _label_length = lm.get_layer('label_length').output
# model.add_loss(ctc_loss)
losses = {
    'ctc':lambda y_true,y_pred:y_pred,
    'classification':'categorical_crossentropy'
}
model.compile(loss=losses, optimizer=adam, metrics=['accuracy'])

# %%
EPOCHS = 30000+42195
model.load_weights('training/unseen_speakers/results/weights_lfw-crop-ctc_classification-v3.hdf5')
hist = model.fit_generator(g_tr
                    , steps_per_epoch=1
                    , epochs=EPOCHS
                    #steps_per_epoch=lip_gen.default_training_steps, epochs=stop_epoch,
                    , validation_data=g_val
                    , validation_steps=1
                    ,callbacks=[checkpoint,tensorboard]
                    ,initial_epoch=42195
                    ,verbose=0)
                    #max_q_size=5,
                    #workers=2,
                    #pickle_safe=True)
# Out:
# Epoch 42196: val_loss did not improve from 0.11136
#
# Epoch 42197: val_loss did not improve from 0.11136
#
# Epoch 42198: val_loss did not improve from 0.11136
#
# Epoch 42199: val_loss did not improve from 0.11136
#
# Epoch 42200: val_loss did not improve from 0.11136
#
# Epoch 42201: val_loss did not improve from 0.11136
#
# Epoch 42202: val_loss did not improve from 0.11136
#
# Epoch 42203: val_loss did not improve from 0.11136
#
# Epoch 42204: val_loss did not improve from 0.11136
#
# Epoch 42205: val_loss did not improve from 0.11136
#
# Epoch 42206: val_loss did not improve from 0.11136
#
# Epoch 42207: val_loss did not improve from 0.11136
#
# Epoch 42208: val_loss did not improve from 0.11136
#
# Epoch 42209: val_loss did not improve from 0.11136
#
# Epoch 42210: val_loss did not improve from 0.11136
#
# Epoch 42211: val_loss did not improve from 0.11136
#
# Epoch 42212: val_loss did not improve from 0.11136
#
# Epoch 42213: val_loss did not improve from 0.11136
#
# Epoch 42214: val_loss did not improve from 0.11136
#
# Epoch 42215: val_loss did not improve from 0.11136
#
# Epoch 42216: val_loss did not improve from 0.11136
#
# Epoch 42217: val_loss did not improve from 0.11136
#
# Epoch 42218: val_loss did not improve from 0.11136
#
# Epoch 42219: val_loss did not improve from 0.11136
#
# Epoch 42220: val_loss did not improve from 0.11136
#
# Epoch 42221: val_loss did not improve from 0.11136
#
# Epoch 42222: val_loss did not improve from 0.11136
#
# Epoch 42223: val_loss did not improve from 0.11136
#
# Epoch 42224: val_loss did not improve from 0.11136
#
# Epoch 42225: val_loss did not improve from 0.11136
#
# Epoch 42226: val_loss did not improve from 0.11136
#
# Epoch 42227: val_loss did not improve from 0.11136
#
# Epoch 42228: val_loss did not improve from 0.11136
#
# Epoch 42229: val_loss did not improve from 0.11136
#
# Epoch 42230: val_loss did not improve from 0.11136
#
# Epoch 42231: val_loss did not improve from 0.11136
#
# Epoch 42232: val_loss did not improve from 0.11136
#
# Epoch 42233: val_loss did not improve from 0.11136
#
# Epoch 42234: val_loss did not improve from 0.11136
#
# Epoch 42235: val_loss did not improve from 0.11136
#
# Epoch 42236: val_loss did not improve from 0.11136
#
# Epoch 42237: val_loss did not improve from 0.11136
#
# Epoch 42238: val_loss did not improve from 0.11136
#
# Epoch 42239: val_loss did not improve from 0.11136
#
# Epoch 42240: val_loss did not improve from 0.11136
#
# Epoch 42241: val_loss did not improve from 0.11136
#
# Epoch 42242: val_loss did not improve from 0.11136
#
# Epoch 42243: val_loss did not improve from 0.11136
#
# Epoch 42244: val_loss did not improve from 0.11136
#
# Epoch 42245: val_loss did not improve from 0.11136
#
# Epoch 42246: val_loss did not improve from 0.11136
#
# Epoch 42247: val_loss did not improve from 0.11136
#
# Epoch 42248: val_loss did not improve from 0.11136
#
# Epoch 42249: val_loss did not improve from 0.11136
#
# Epoch 42250: val_loss did not improve from 0.11136
#
# Epoch 42251: val_loss did not improve from 0.11136
#
# Epoch 42252: val_loss did not improve from 0.11136
#
# Epoch 42253: val_loss did not improve from 0.11136
#
# Epoch 42254: val_loss did not improve from 0.11136
#
# Epoch 42255: val_loss did not improve from 0.11136
#
# Epoch 42256: val_loss did not improve from 0.11136
#
# Epoch 42257: val_loss did not improve from 0.11136
#
# Epoch 42258: val_loss did not improve from 0.11136
#
# Epoch 42259: val_loss did not improve from 0.11136
#
# Epoch 42260: val_loss did not improve from 0.11136
#
# Epoch 42261: val_loss did not improve from 0.11136
#
# Epoch 42262: val_loss did not improve from 0.11136
#
# Epoch 42263: val_loss did not improve from 0.11136
#
# Epoch 42264: val_loss did not improve from 0.11136
#
# Epoch 42265: val_loss did not improve from 0.11136
#
# Epoch 42266: val_loss did not improve from 0.11136
#
# Epoch 42267: val_loss did not improve from 0.11136
#
# Epoch 42268: val_loss did not improve from 0.11136
#
# Epoch 42269: val_loss did not improve from 0.11136
#
# Epoch 42270: val_loss did not improve from 0.11136
#
# Epoch 42271: val_loss did not improve from 0.11136
#
# Epoch 42272: val_loss did not improve from 0.11136
#
# Epoch 42273: val_loss did not improve from 0.11136
#
# Epoch 42274: val_loss did not improve from 0.11136
#
# Epoch 42275: val_loss did not improve from 0.11136
#
# Epoch 42276: val_loss did not improve from 0.11136
#
# Epoch 42277: val_loss did not improve from 0.11136
#
# Epoch 42278: val_loss did not improve from 0.11136
#
# Epoch 42279: val_loss did not improve from 0.11136
#
# Epoch 42280: val_loss did not improve from 0.11136
#
# Epoch 42281: val_loss did not improve from 0.11136
#
# Epoch 42282: val_loss did not improve from 0.11136
#
# Epoch 42283: val_loss did not improve from 0.11136
#
# Epoch 42284: val_loss did not improve from 0.11136
#
# Epoch 42285: val_loss did not improve from 0.11136
#
# Epoch 42286: val_loss did not improve from 0.11136
#
# Epoch 42287: val_loss did not improve from 0.11136
#
# Epoch 42288: val_loss did not improve from 0.11136
#
# Epoch 42289: val_loss did not improve from 0.11136
#
# Epoch 42290: val_loss did not improve from 0.11136
#
# Epoch 42291: val_loss did not improve from 0.11136
#
# Epoch 42292: val_loss did not improve from 0.11136
#
# Epoch 42293: val_loss did not improve from 0.11136
#
# Epoch 42294: val_loss did not improve from 0.11136
#
# Epoch 42295: val_loss did not improve from 0.11136
#
# Epoch 42296: val_loss did not improve from 0.11136
#
# Epoch 42297: val_loss did not improve from 0.11136
#
# Epoch 42298: val_loss did not improve from 0.11136
#
# Epoch 42299: val_loss did not improve from 0.11136
#
# Epoch 42300: val_loss did not improve from 0.11136
#
# Epoch 42301: val_loss did not improve from 0.11136
#
# Epoch 42302: val_loss did not improve from 0.11136
#
# Epoch 42303: val_loss did not improve from 0.11136
#
# Epoch 42304: val_loss did not improve from 0.11136
#
# Epoch 42305: val_loss did not improve from 0.11136
#
# Epoch 42306: val_loss did not improve from 0.11136
#
# Epoch 42307: val_loss did not improve from 0.11136
#
# Epoch 42308: val_loss did not improve from 0.11136
#
# Epoch 42309: val_loss did not improve from 0.11136
#
# Epoch 42310: val_loss did not improve from 0.11136
#
# Epoch 42311: val_loss did not improve from 0.11136
#
# Epoch 42312: val_loss did not improve from 0.11136
#
# Epoch 42313: val_loss did not improve from 0.11136
#
# Epoch 42314: val_loss did not improve from 0.11136
#
# Epoch 42315: val_loss did not improve from 0.11136
#
# Epoch 42316: val_loss did not improve from 0.11136
#
# Epoch 42317: val_loss did not improve from 0.11136
#
# Epoch 42318: val_loss did not improve from 0.11136
#
# Epoch 42319: val_loss did not improve from 0.11136
#
# Epoch 42320: val_loss did not improve from 0.11136
#
# Epoch 42321: val_loss did not improve from 0.11136
#
# Epoch 42322: val_loss did not improve from 0.11136
#
# Epoch 42323: val_loss did not improve from 0.11136
#
# Epoch 42324: val_loss did not improve from 0.11136
#
# Epoch 42325: val_loss did not improve from 0.11136
#
# Epoch 42326: val_loss did not improve from 0.11136
#
# Epoch 42327: val_loss did not improve from 0.11136
#
# Epoch 42328: val_loss did not improve from 0.11136
#
# Epoch 42329: val_loss did not improve from 0.11136
#
# Epoch 42330: val_loss did not improve from 0.11136
#
# Epoch 42331: val_loss did not improve from 0.11136
#
# Epoch 42332: val_loss did not improve from 0.11136
#
# Epoch 42333: val_loss did not improve from 0.11136
#
# Epoch 42334: val_loss did not improve from 0.11136
#
# Epoch 42335: val_loss did not improve from 0.11136
#
# Epoch 42336: val_loss did not improve from 0.11136
#
# Epoch 42337: val_loss did not improve from 0.11136
#
# Epoch 42338: val_loss did not improve from 0.11136
#
# Epoch 42339: val_loss did not improve from 0.11136
#
# Epoch 42340: val_loss did not improve from 0.11136
#
# Epoch 42341: val_loss did not improve from 0.11136
#
# Epoch 42342: val_loss did not improve from 0.11136
#
# Epoch 42343: val_loss did not improve from 0.11136
#
# Epoch 42344: val_loss did not improve from 0.11136
#
# Epoch 42345: val_loss did not improve from 0.11136
#
# Epoch 42346: val_loss did not improve from 0.11136
#
# Epoch 42347: val_loss did not improve from 0.11136
#
# Epoch 42348: val_loss did not improve from 0.11136
#
# Epoch 42349: val_loss did not improve from 0.11136
#
# Epoch 42350: val_loss did not improve from 0.11136
#
# Epoch 42351: val_loss did not improve from 0.11136
#
# Epoch 42352: val_loss did not improve from 0.11136
#
# Epoch 42353: val_loss did not improve from 0.11136
# Epoch 42354: val_loss did not improve from 0.11136
#
# Epoch 42355: val_loss did not improve from 0.11136
#
# Epoch 42356: val_loss did not improve from 0.11136
#
# Epoch 42357: val_loss did not improve from 0.11136
#
# Epoch 42358: val_loss did not improve from 0.11136
#
# Epoch 42359: val_loss did not improve from 0.11136
#
# Epoch 42360: val_loss did not improve from 0.11136
#
# Epoch 42361: val_loss did not improve from 0.11136
#
# Epoch 42362: val_loss did not improve from 0.11136
#
# Epoch 42363: val_loss did not improve from 0.11136
#
# Epoch 42364: val_loss did not improve from 0.11136
#
# Epoch 42365: val_loss did not improve from 0.11136
#
# Epoch 42366: val_loss did not improve from 0.11136
#
# Epoch 42367: val_loss did not improve from 0.11136
#
# Epoch 42368: val_loss did not improve from 0.11136
#
# Epoch 42369: val_loss did not improve from 0.11136
#
# Epoch 42370: val_loss did not improve from 0.11136
#
# Epoch 42371: val_loss did not improve from 0.11136
#
# Epoch 42372: val_loss did not improve from 0.11136
#
# Epoch 42373: val_loss did not improve from 0.11136
#
# Epoch 42374: val_loss did not improve from 0.11136
#
# Epoch 42375: val_loss did not improve from 0.11136
#
# Epoch 42376: val_loss did not improve from 0.11136
#
# Epoch 42377: val_loss did not improve from 0.11136
#
# Epoch 42378: val_loss did not improve from 0.11136
#
# Epoch 42379: val_loss did not improve from 0.11136
#
# Epoch 42380: val_loss did not improve from 0.11136
#
# Epoch 42381: val_loss did not improve from 0.11136
#
# Epoch 42382: val_loss did not improve from 0.11136
#
# Epoch 42383: val_loss did not improve from 0.11136
#
# Epoch 42384: val_loss did not improve from 0.11136
#
# Epoch 42385: val_loss did not improve from 0.11136
#
# Epoch 42386: val_loss did not improve from 0.11136
#
# Epoch 42387: val_loss did not improve from 0.11136
#
# Epoch 42388: val_loss did not improve from 0.11136
#
# Epoch 42389: val_loss did not improve from 0.11136
#
# Epoch 42390: val_loss did not improve from 0.11136
#
# Epoch 42391: val_loss did not improve from 0.11136
#
# Epoch 42392: val_loss did not improve from 0.11136
#
# Epoch 42393: val_loss did not improve from 0.11136
#
# Epoch 42394: val_loss did not improve from 0.11136
#
# Epoch 42395: val_loss did not improve from 0.11136
#
# Epoch 42396: val_loss did not improve from 0.11136
#
# Epoch 42397: val_loss did not improve from 0.11136
#
# Epoch 42398: val_loss did not improve from 0.11136
#
# Epoch 42399: val_loss did not improve from 0.11136
#
# Epoch 42400: val_loss did not improve from 0.11136
#
# Epoch 42401: val_loss did not improve from 0.11136
#
# Epoch 42402: val_loss did not improve from 0.11136
#
# Epoch 42403: val_loss did not improve from 0.11136
#
# Epoch 42404: val_loss did not improve from 0.11136
#
# Epoch 42405: val_loss did not improve from 0.11136
#
# Epoch 42406: val_loss did not improve from 0.11136
#
# Epoch 42407: val_loss did not improve from 0.11136
#
# Epoch 42408: val_loss did not improve from 0.11136
#
# Epoch 42409: val_loss did not improve from 0.11136
#
# Epoch 42410: val_loss did not improve from 0.11136
#
# Epoch 42411: val_loss did not improve from 0.11136
#
# Epoch 42412: val_loss did not improve from 0.11136
#
# Epoch 42413: val_loss did not improve from 0.11136
#
# Epoch 42414: val_loss did not improve from 0.11136
#
# Epoch 42415: val_loss did not improve from 0.11136
#
# Epoch 42416: val_loss did not improve from 0.11136
#
# Epoch 42417: val_loss did not improve from 0.11136
#
# Epoch 42418: val_loss did not improve from 0.11136
#
# Epoch 42419: val_loss did not improve from 0.11136
#
# Epoch 42420: val_loss did not improve from 0.11136
#
# Epoch 42421: val_loss did not improve from 0.11136
#
# Epoch 42422: val_loss did not improve from 0.11136
#
# Epoch 42423: val_loss did not improve from 0.11136
#
# Epoch 42424: val_loss did not improve from 0.11136
#
# Epoch 42425: val_loss did not improve from 0.11136
#
# Epoch 42426: val_loss did not improve from 0.11136
#
# Epoch 42427: val_loss did not improve from 0.11136
#
# Epoch 42428: val_loss did not improve from 0.11136
#
# Epoch 42429: val_loss did not improve from 0.11136
#
# Epoch 42430: val_loss did not improve from 0.11136
#
# Epoch 42431: val_loss did not improve from 0.11136
#
# Epoch 42432: val_loss did not improve from 0.11136
#
# Epoch 42433: val_loss did not improve from 0.11136
#
# Epoch 42434: val_loss did not improve from 0.11136
#
# Epoch 42435: val_loss did not improve from 0.11136
#
# Epoch 42436: val_loss did not improve from 0.11136
#
# Epoch 42437: val_loss did not improve from 0.11136
#
# Epoch 42438: val_loss did not improve from 0.11136
#
# Epoch 42439: val_loss did not improve from 0.11136
#
# Epoch 42440: val_loss did not improve from 0.11136
#
# Epoch 42441: val_loss did not improve from 0.11136
#
# Epoch 42442: val_loss did not improve from 0.11136
#
# Epoch 42443: val_loss did not improve from 0.11136
#
# Epoch 42444: val_loss did not improve from 0.11136
#
# Epoch 42445: val_loss did not improve from 0.11136
#
# Epoch 42446: val_loss did not improve from 0.11136
#
# Epoch 42447: val_loss did not improve from 0.11136
#
# Epoch 42448: val_loss did not improve from 0.11136
#
# Epoch 42449: val_loss did not improve from 0.11136
#
# Epoch 42450: val_loss did not improve from 0.11136
#
# Epoch 42451: val_loss did not improve from 0.11136
#
# Epoch 42452: val_loss did not improve from 0.11136
#
# Epoch 42453: val_loss did not improve from 0.11136
#
# Epoch 42454: val_loss did not improve from 0.11136
#
# Epoch 42455: val_loss did not improve from 0.11136
#
# Epoch 42456: val_loss did not improve from 0.11136
#
# Epoch 42457: val_loss did not improve from 0.11136
#
# Epoch 42458: val_loss did not improve from 0.11136
#
# Epoch 42459: val_loss did not improve from 0.11136
#
# Epoch 42460: val_loss did not improve from 0.11136
#
# Epoch 42461: val_loss did not improve from 0.11136
#
# Epoch 42462: val_loss did not improve from 0.11136
#
# Epoch 42463: val_loss did not improve from 0.11136
#
# Epoch 42464: val_loss did not improve from 0.11136
#
# Epoch 42465: val_loss did not improve from 0.11136
#
# Epoch 42466: val_loss did not improve from 0.11136
#
# Epoch 42467: val_loss did not improve from 0.11136
#
# Epoch 42468: val_loss did not improve from 0.11136
#
# Epoch 42469: val_loss did not improve from 0.11136
#
# Epoch 42470: val_loss did not improve from 0.11136
#
# Epoch 42471: val_loss did not improve from 0.11136
#
# Epoch 42472: val_loss did not improve from 0.11136
#
# Epoch 42473: val_loss did not improve from 0.11136
#
# Epoch 42474: val_loss did not improve from 0.11136
#
# Epoch 42475: val_loss did not improve from 0.11136
#
# Epoch 42476: val_loss did not improve from 0.11136
#
# Epoch 42477: val_loss did not improve from 0.11136
#
# Epoch 42478: val_loss did not improve from 0.11136
#
# Epoch 42479: val_loss did not improve from 0.11136
#
# Epoch 42480: val_loss did not improve from 0.11136
#
# Epoch 42481: val_loss did not improve from 0.11136
#
# Epoch 42482: val_loss did not improve from 0.11136
#
# Epoch 42483: val_loss did not improve from 0.11136
#
# Epoch 42484: val_loss did not improve from 0.11136
#
# Epoch 42485: val_loss did not improve from 0.11136
#
# Epoch 42486: val_loss did not improve from 0.11136
#
# Epoch 42487: val_loss did not improve from 0.11136
#
# Epoch 42488: val_loss did not improve from 0.11136
#
# Epoch 42489: val_loss did not improve from 0.11136
#
# Epoch 42490: val_loss did not improve from 0.11136
#
# Epoch 42491: val_loss did not improve from 0.11136
#
# Epoch 42492: val_loss did not improve from 0.11136
#
# Epoch 42493: val_loss did not improve from 0.11136
#
# Epoch 42494: val_loss did not improve from 0.11136
#
# Epoch 42495: val_loss did not improve from 0.11136
#
# Epoch 42496: val_loss did not improve from 0.11136
#
# Epoch 42497: val_loss did not improve from 0.11136
#
# Epoch 42498: val_loss did not improve from 0.11136
#
# Epoch 42499: val_loss did not improve from 0.11136
#
# Epoch 42500: val_loss did not improve from 0.11136
#
# Epoch 42501: val_loss did not improve from 0.11136
#
# Epoch 42502: val_loss did not improve from 0.11136
#
# Epoch 42503: val_loss did not improve from 0.11136
#
# Epoch 42504: val_loss did not improve from 0.11136
#
# Epoch 42505: val_loss did not improve from 0.11136
#
# Epoch 42506: val_loss did not improve from 0.11136
#
# Epoch 42507: val_loss did not improve from 0.11136
#
# Epoch 42508: val_loss did not improve from 0.11136
#
# Epoch 42509: val_loss did not improve from 0.11136
#
# Epoch 42510: val_loss did not improve from 0.11136
#
# Epoch 42511: val_loss did not improve from 0.11136
# Epoch 42512: val_loss did not improve from 0.11136
#
# Epoch 42513: val_loss did not improve from 0.11136
#
# Epoch 42514: val_loss did not improve from 0.11136
#
# Epoch 42515: val_loss did not improve from 0.11136
#
# Epoch 42516: val_loss did not improve from 0.11136
#
# Epoch 42517: val_loss did not improve from 0.11136
#
# Epoch 42518: val_loss did not improve from 0.11136
#
# Epoch 42519: val_loss did not improve from 0.11136
#
# Epoch 42520: val_loss did not improve from 0.11136
#
# Epoch 42521: val_loss did not improve from 0.11136
#
# Epoch 42522: val_loss did not improve from 0.11136
#
# Epoch 42523: val_loss did not improve from 0.11136
#
# Epoch 42524: val_loss did not improve from 0.11136
#
# Epoch 42525: val_loss did not improve from 0.11136
#
# Epoch 42526: val_loss did not improve from 0.11136
#
# Epoch 42527: val_loss did not improve from 0.11136
#
# Epoch 42528: val_loss did not improve from 0.11136
#
# Epoch 42529: val_loss did not improve from 0.11136
#
# Epoch 42530: val_loss did not improve from 0.11136
#
# Epoch 42531: val_loss did not improve from 0.11136
#
# Epoch 42532: val_loss did not improve from 0.11136
#
# Epoch 42533: val_loss did not improve from 0.11136
#
# Epoch 42534: val_loss did not improve from 0.11136
#
# Epoch 42535: val_loss did not improve from 0.11136
#
# Epoch 42536: val_loss did not improve from 0.11136
#
# Epoch 42537: val_loss did not improve from 0.11136
#
# Epoch 42538: val_loss did not improve from 0.11136
#
# Epoch 42539: val_loss did not improve from 0.11136
#
# Epoch 42540: val_loss did not improve from 0.11136
#
# Epoch 42541: val_loss did not improve from 0.11136
#
# Epoch 42542: val_loss did not improve from 0.11136
#
# Epoch 42543: val_loss did not improve from 0.11136
#
# Epoch 42544: val_loss did not improve from 0.11136
#
# Epoch 42545: val_loss did not improve from 0.11136
#
# Epoch 42546: val_loss did not improve from 0.11136
#
# Epoch 42547: val_loss did not improve from 0.11136
#
# Epoch 42548: val_loss did not improve from 0.11136
#
# Epoch 42549: val_loss did not improve from 0.11136
#
# Epoch 42550: val_loss did not improve from 0.11136
#
# Epoch 42551: val_loss did not improve from 0.11136
#
# Epoch 42552: val_loss did not improve from 0.11136
#
# Epoch 42553: val_loss did not improve from 0.11136
#
# Epoch 42554: val_loss did not improve from 0.11136
#
# Epoch 42555: val_loss did not improve from 0.11136
#
# Epoch 42556: val_loss did not improve from 0.11136
#
# Epoch 42557: val_loss did not improve from 0.11136
#
# Epoch 42558: val_loss did not improve from 0.11136
#
# Epoch 42559: val_loss did not improve from 0.11136
#
# Epoch 42560: val_loss did not improve from 0.11136
#
# Epoch 42561: val_loss did not improve from 0.11136
#
# Epoch 42562: val_loss did not improve from 0.11136
#
# Epoch 42563: val_loss did not improve from 0.11136
#
# Epoch 42564: val_loss did not improve from 0.11136
#
# Epoch 42565: val_loss did not improve from 0.11136
#
# Epoch 42566: val_loss did not improve from 0.11136
#
# Epoch 42567: val_loss did not improve from 0.11136
#
# Epoch 42568: val_loss did not improve from 0.11136
#
# Epoch 42569: val_loss did not improve from 0.11136
#
# Epoch 42570: val_loss did not improve from 0.11136
#
# Epoch 42571: val_loss did not improve from 0.11136
#
# Epoch 42572: val_loss did not improve from 0.11136
#
# Epoch 42573: val_loss did not improve from 0.11136
#
# Epoch 42574: val_loss did not improve from 0.11136
#
# Epoch 42575: val_loss did not improve from 0.11136
#
# Epoch 42576: val_loss did not improve from 0.11136
#
# Epoch 42577: val_loss did not improve from 0.11136
#
# Epoch 42578: val_loss did not improve from 0.11136
#
# Epoch 42579: val_loss did not improve from 0.11136
#
# Epoch 42580: val_loss did not improve from 0.11136
#
# Epoch 42581: val_loss did not improve from 0.11136
#
# Epoch 42582: val_loss did not improve from 0.11136
#
# Epoch 42583: val_loss did not improve from 0.11136
#
# Epoch 42584: val_loss did not improve from 0.11136
#
# Epoch 42585: val_loss did not improve from 0.11136
#
# Epoch 42586: val_loss did not improve from 0.11136
#
# Epoch 42587: val_loss did not improve from 0.11136
#
# Epoch 42588: val_loss did not improve from 0.11136
#
# Epoch 42589: val_loss did not improve from 0.11136
#
# Epoch 42590: val_loss did not improve from 0.11136
#
# Epoch 42591: val_loss did not improve from 0.11136
#
# Epoch 42592: val_loss did not improve from 0.11136
#
# Epoch 42593: val_loss did not improve from 0.11136
#
# Epoch 42594: val_loss did not improve from 0.11136
#
# Epoch 42595: val_loss did not improve from 0.11136
#
# Epoch 42596: val_loss did not improve from 0.11136
#
# Epoch 42597: val_loss did not improve from 0.11136
#
# Epoch 42598: val_loss did not improve from 0.11136
#
# Epoch 42599: val_loss did not improve from 0.11136
#
# Epoch 42600: val_loss did not improve from 0.11136
#
# Epoch 42601: val_loss did not improve from 0.11136
#
# Epoch 42602: val_loss did not improve from 0.11136
#
# Epoch 42603: val_loss did not improve from 0.11136
#
# Epoch 42604: val_loss did not improve from 0.11136
#
# Epoch 42605: val_loss did not improve from 0.11136
#
# Epoch 42606: val_loss did not improve from 0.11136
#
# Epoch 42607: val_loss did not improve from 0.11136
#
# Epoch 42608: val_loss did not improve from 0.11136
#
# Epoch 42609: val_loss did not improve from 0.11136
#
# Epoch 42610: val_loss did not improve from 0.11136
#
# Epoch 42611: val_loss did not improve from 0.11136
#
# Epoch 42612: val_loss did not improve from 0.11136
#
# Epoch 42613: val_loss did not improve from 0.11136
#
# Epoch 42614: val_loss did not improve from 0.11136
#
# Epoch 42615: val_loss did not improve from 0.11136
#
# Epoch 42616: val_loss did not improve from 0.11136
#
# Epoch 42617: val_loss did not improve from 0.11136
#
# Epoch 42618: val_loss did not improve from 0.11136
#
# Epoch 42619: val_loss did not improve from 0.11136
#
# Epoch 42620: val_loss did not improve from 0.11136
#
# Epoch 42621: val_loss did not improve from 0.11136
#
# Epoch 42622: val_loss did not improve from 0.11136
#
# Epoch 42623: val_loss did not improve from 0.11136
#
# Epoch 42624: val_loss did not improve from 0.11136
#
# Epoch 42625: val_loss did not improve from 0.11136
#
# Epoch 42626: val_loss did not improve from 0.11136
#
# Epoch 42627: val_loss did not improve from 0.11136
#
# Epoch 42628: val_loss did not improve from 0.11136
#
# Epoch 42629: val_loss did not improve from 0.11136
#
# Epoch 42630: val_loss did not improve from 0.11136
#
# Epoch 42631: val_loss did not improve from 0.11136
#
# Epoch 42632: val_loss did not improve from 0.11136
#
# Epoch 42633: val_loss did not improve from 0.11136
#
# Epoch 42634: val_loss did not improve from 0.11136
#
# Epoch 42635: val_loss did not improve from 0.11136
#
# Epoch 42636: val_loss did not improve from 0.11136
#
# Epoch 42637: val_loss did not improve from 0.11136
#
# Epoch 42638: val_loss did not improve from 0.11136
#
# Epoch 42639: val_loss did not improve from 0.11136
#
# Epoch 42640: val_loss did not improve from 0.11136
#
# Epoch 42641: val_loss did not improve from 0.11136
#
# Epoch 42642: val_loss did not improve from 0.11136
#
# Epoch 42643: val_loss did not improve from 0.11136
#
# Epoch 42644: val_loss did not improve from 0.11136
#
# Epoch 42645: val_loss did not improve from 0.11136
#
# Epoch 42646: val_loss did not improve from 0.11136
#
# Epoch 42647: val_loss did not improve from 0.11136
#
# Epoch 42648: val_loss did not improve from 0.11136
#
# Epoch 42649: val_loss did not improve from 0.11136
#
# Epoch 42650: val_loss did not improve from 0.11136
#
# Epoch 42651: val_loss did not improve from 0.11136
#
# Epoch 42652: val_loss did not improve from 0.11136
#
# Epoch 42653: val_loss did not improve from 0.11136
#
# Epoch 42654: val_loss did not improve from 0.11136
#
# Epoch 42655: val_loss did not improve from 0.11136
#
# Epoch 42656: val_loss did not improve from 0.11136
#
# Epoch 42657: val_loss did not improve from 0.11136
#
# Epoch 42658: val_loss did not improve from 0.11136
#
# Epoch 42659: val_loss did not improve from 0.11136
#
# Epoch 42660: val_loss did not improve from 0.11136
#
# Epoch 42661: val_loss did not improve from 0.11136
#
# Epoch 42662: val_loss did not improve from 0.11136
#
# Epoch 42663: val_loss did not improve from 0.11136
#
# Epoch 42664: val_loss did not improve from 0.11136
#
# Epoch 42665: val_loss did not improve from 0.11136
#
# Epoch 42666: val_loss did not improve from 0.11136
#
# Epoch 42667: val_loss did not improve from 0.11136
#
# Epoch 42668: val_loss did not improve from 0.11136
#
# Epoch 42669: val_loss did not improve from 0.11136
# Epoch 42670: val_loss did not improve from 0.11136
#
# Epoch 42671: val_loss did not improve from 0.11136
#
# Epoch 42672: val_loss did not improve from 0.11136
#
# Epoch 42673: val_loss did not improve from 0.11136
#
# Epoch 42674: val_loss did not improve from 0.11136
#
# Epoch 42675: val_loss did not improve from 0.11136
#
# Epoch 42676: val_loss did not improve from 0.11136
#
# Epoch 42677: val_loss did not improve from 0.11136
#
# Epoch 42678: val_loss did not improve from 0.11136
#
# Epoch 42679: val_loss did not improve from 0.11136
#
# Epoch 42680: val_loss did not improve from 0.11136
#
# Epoch 42681: val_loss did not improve from 0.11136
#
# Epoch 42682: val_loss did not improve from 0.11136
#
# Epoch 42683: val_loss did not improve from 0.11136
#
# Epoch 42684: val_loss did not improve from 0.11136
#
# Epoch 42685: val_loss did not improve from 0.11136
#
# Epoch 42686: val_loss did not improve from 0.11136
#
# Epoch 42687: val_loss did not improve from 0.11136
#
# Epoch 42688: val_loss did not improve from 0.11136
#
# Epoch 42689: val_loss did not improve from 0.11136
#
# Epoch 42690: val_loss did not improve from 0.11136
#
# Epoch 42691: val_loss did not improve from 0.11136
#
# Epoch 42692: val_loss did not improve from 0.11136
#
# Epoch 42693: val_loss did not improve from 0.11136
#
# Epoch 42694: val_loss did not improve from 0.11136
#
# Epoch 42695: val_loss did not improve from 0.11136
#
# Epoch 42696: val_loss did not improve from 0.11136
#
# Epoch 42697: val_loss did not improve from 0.11136
#
# Epoch 42698: val_loss did not improve from 0.11136
#
# Epoch 42699: val_loss did not improve from 0.11136
#
# Epoch 42700: val_loss did not improve from 0.11136
#
# Epoch 42701: val_loss did not improve from 0.11136
#
# Epoch 42702: val_loss did not improve from 0.11136
#
# Epoch 42703: val_loss did not improve from 0.11136
#
# Epoch 42704: val_loss did not improve from 0.11136
#
# Epoch 42705: val_loss did not improve from 0.11136
#
# Epoch 42706: val_loss did not improve from 0.11136
#
# Epoch 42707: val_loss did not improve from 0.11136
#
# Epoch 42708: val_loss did not improve from 0.11136
#
# Epoch 42709: val_loss did not improve from 0.11136
#
# Epoch 42710: val_loss did not improve from 0.11136
#
# Epoch 42711: val_loss did not improve from 0.11136
#
# Epoch 42712: val_loss did not improve from 0.11136
#
# Epoch 42713: val_loss did not improve from 0.11136
#
# Epoch 42714: val_loss did not improve from 0.11136
#
# Epoch 42715: val_loss did not improve from 0.11136
#
# Epoch 42716: val_loss did not improve from 0.11136
#
# Epoch 42717: val_loss did not improve from 0.11136
#
# Epoch 42718: val_loss did not improve from 0.11136
#
# Epoch 42719: val_loss did not improve from 0.11136
#
# Epoch 42720: val_loss did not improve from 0.11136
#
# Epoch 42721: val_loss did not improve from 0.11136
#
# Epoch 42722: val_loss did not improve from 0.11136
#
# Epoch 42723: val_loss did not improve from 0.11136
#
# Epoch 42724: val_loss did not improve from 0.11136
#
# Epoch 42725: val_loss did not improve from 0.11136
#
# Epoch 42726: val_loss did not improve from 0.11136
#
# Epoch 42727: val_loss did not improve from 0.11136
#
# Epoch 42728: val_loss did not improve from 0.11136
#
# Epoch 42729: val_loss did not improve from 0.11136
#
# Epoch 42730: val_loss did not improve from 0.11136
#
# Epoch 42731: val_loss did not improve from 0.11136
#
# Epoch 42732: val_loss did not improve from 0.11136
#
# Epoch 42733: val_loss did not improve from 0.11136
#
# Epoch 42734: val_loss did not improve from 0.11136
#
# Epoch 42735: val_loss did not improve from 0.11136
#
# Epoch 42736: val_loss did not improve from 0.11136
#
# Epoch 42737: val_loss did not improve from 0.11136
#
# Epoch 42738: val_loss did not improve from 0.11136
#
# Epoch 42739: val_loss did not improve from 0.11136
#
# Epoch 42740: val_loss did not improve from 0.11136
#
# Epoch 42741: val_loss did not improve from 0.11136
#
# Epoch 42742: val_loss did not improve from 0.11136
#
# Epoch 42743: val_loss did not improve from 0.11136
#
# Epoch 42744: val_loss did not improve from 0.11136
#
# Epoch 42745: val_loss did not improve from 0.11136
#
# Epoch 42746: val_loss did not improve from 0.11136
#
# Epoch 42747: val_loss did not improve from 0.11136
#
# Epoch 42748: val_loss did not improve from 0.11136
#
# Epoch 42749: val_loss did not improve from 0.11136
#
# Epoch 42750: val_loss did not improve from 0.11136
#
# Epoch 42751: val_loss did not improve from 0.11136
#
# Epoch 42752: val_loss did not improve from 0.11136
#
# Epoch 42753: val_loss did not improve from 0.11136
#
# Epoch 42754: val_loss did not improve from 0.11136
#
# Epoch 42755: val_loss did not improve from 0.11136
#
# Epoch 42756: val_loss did not improve from 0.11136
#
# Epoch 42757: val_loss did not improve from 0.11136
#
# Epoch 42758: val_loss did not improve from 0.11136
#
# Epoch 42759: val_loss did not improve from 0.11136
#
# Epoch 42760: val_loss did not improve from 0.11136
#
# Epoch 42761: val_loss did not improve from 0.11136
#
# Epoch 42762: val_loss did not improve from 0.11136
#
# Epoch 42763: val_loss did not improve from 0.11136
#
# Epoch 42764: val_loss did not improve from 0.11136
#
# Epoch 42765: val_loss did not improve from 0.11136
#
# Epoch 42766: val_loss did not improve from 0.11136
#
# Epoch 42767: val_loss did not improve from 0.11136
#
# Epoch 42768: val_loss did not improve from 0.11136
#
# Epoch 42769: val_loss did not improve from 0.11136
#
# Epoch 42770: val_loss did not improve from 0.11136
#
# Epoch 42771: val_loss did not improve from 0.11136
#
# Epoch 42772: val_loss did not improve from 0.11136
#
# Epoch 42773: val_loss did not improve from 0.11136
#
# Epoch 42774: val_loss did not improve from 0.11136
#
# Epoch 42775: val_loss did not improve from 0.11136
#
# Epoch 42776: val_loss did not improve from 0.11136
#
# Epoch 42777: val_loss did not improve from 0.11136
#
# Epoch 42778: val_loss did not improve from 0.11136
#
# Epoch 42779: val_loss did not improve from 0.11136
#
# Epoch 42780: val_loss did not improve from 0.11136
#
# Epoch 42781: val_loss did not improve from 0.11136
#
# Epoch 42782: val_loss did not improve from 0.11136
#
# Epoch 42783: val_loss did not improve from 0.11136
#
# Epoch 42784: val_loss did not improve from 0.11136
#
# Epoch 42785: val_loss did not improve from 0.11136
#
# Epoch 42786: val_loss did not improve from 0.11136
#
# Epoch 42787: val_loss did not improve from 0.11136
#
# Epoch 42788: val_loss did not improve from 0.11136
#
# Epoch 42789: val_loss did not improve from 0.11136
#
# Epoch 42790: val_loss did not improve from 0.11136
#
# Epoch 42791: val_loss did not improve from 0.11136
#
# Epoch 42792: val_loss did not improve from 0.11136
#
# Epoch 42793: val_loss did not improve from 0.11136
#
# Epoch 42794: val_loss did not improve from 0.11136
#
# Epoch 42795: val_loss did not improve from 0.11136
#
# Epoch 42796: val_loss did not improve from 0.11136
#
# Epoch 42797: val_loss did not improve from 0.11136
#
# Epoch 42798: val_loss did not improve from 0.11136
#
# Epoch 42799: val_loss did not improve from 0.11136
#
# Epoch 42800: val_loss did not improve from 0.11136
#
# Epoch 42801: val_loss did not improve from 0.11136
#
# Epoch 42802: val_loss did not improve from 0.11136
#
# Epoch 42803: val_loss did not improve from 0.11136
#
# Epoch 42804: val_loss did not improve from 0.11136
#
# Epoch 42805: val_loss did not improve from 0.11136
#
# Epoch 42806: val_loss did not improve from 0.11136
#
# Epoch 42807: val_loss did not improve from 0.11136
#
# Epoch 42808: val_loss did not improve from 0.11136
#
# Epoch 42809: val_loss did not improve from 0.11136
#
# Epoch 42810: val_loss did not improve from 0.11136
#
# Epoch 42811: val_loss did not improve from 0.11136
#
# Epoch 42812: val_loss did not improve from 0.11136
#
# Epoch 42813: val_loss did not improve from 0.11136
#
# Epoch 42814: val_loss did not improve from 0.11136
#
# Epoch 42815: val_loss did not improve from 0.11136
#
# Epoch 42816: val_loss did not improve from 0.11136
#
# Epoch 42817: val_loss did not improve from 0.11136
#
# Epoch 42818: val_loss did not improve from 0.11136
#
# Epoch 42819: val_loss did not improve from 0.11136
#
# Epoch 42820: val_loss did not improve from 0.11136
#
# Epoch 42821: val_loss did not improve from 0.11136
#
# Epoch 42822: val_loss did not improve from 0.11136
#
# Epoch 42823: val_loss did not improve from 0.11136
#
# Epoch 42824: val_loss did not improve from 0.11136
#
# Epoch 42825: val_loss did not improve from 0.11136
#
# Epoch 42826: val_loss did not improve from 0.11136
#
# Epoch 42827: val_loss did not improve from 0.11136
# Epoch 42828: val_loss did not improve from 0.11136
#
# Epoch 42829: val_loss did not improve from 0.11136
#
# Epoch 42830: val_loss did not improve from 0.11136
#
# Epoch 42831: val_loss did not improve from 0.11136
#
# Epoch 42832: val_loss did not improve from 0.11136
#
# Epoch 42833: val_loss did not improve from 0.11136
#
# Epoch 42834: val_loss did not improve from 0.11136
#
# Epoch 42835: val_loss did not improve from 0.11136
#
# Epoch 42836: val_loss did not improve from 0.11136
#
# Epoch 42837: val_loss did not improve from 0.11136
#
# Epoch 42838: val_loss did not improve from 0.11136
#
# Epoch 42839: val_loss did not improve from 0.11136
#
# Epoch 42840: val_loss did not improve from 0.11136
#
# Epoch 42841: val_loss did not improve from 0.11136
#
# Epoch 42842: val_loss did not improve from 0.11136
#
# Epoch 42843: val_loss did not improve from 0.11136
#
# Epoch 42844: val_loss did not improve from 0.11136
#
# Epoch 42845: val_loss did not improve from 0.11136
#
# Epoch 42846: val_loss did not improve from 0.11136
#
# Epoch 42847: val_loss did not improve from 0.11136
#
# Epoch 42848: val_loss did not improve from 0.11136
#
# Epoch 42849: val_loss did not improve from 0.11136
#
# Epoch 42850: val_loss did not improve from 0.11136
#
# Epoch 42851: val_loss did not improve from 0.11136
#
# Epoch 42852: val_loss did not improve from 0.11136
#
# Epoch 42853: val_loss did not improve from 0.11136
#
# Epoch 42854: val_loss did not improve from 0.11136
#
# Epoch 42855: val_loss did not improve from 0.11136
#
# Epoch 42856: val_loss did not improve from 0.11136
#
# Epoch 42857: val_loss did not improve from 0.11136
#
# Epoch 42858: val_loss did not improve from 0.11136
#
# Epoch 42859: val_loss did not improve from 0.11136
#
# Epoch 42860: val_loss did not improve from 0.11136
#
# Epoch 42861: val_loss did not improve from 0.11136
#
# Epoch 42862: val_loss did not improve from 0.11136
#
# Epoch 42863: val_loss did not improve from 0.11136
#
# Epoch 42864: val_loss did not improve from 0.11136
#
# Epoch 42865: val_loss did not improve from 0.11136
#
# Epoch 42866: val_loss did not improve from 0.11136
#
# Epoch 42867: val_loss did not improve from 0.11136
#
# Epoch 42868: val_loss did not improve from 0.11136
#
# Epoch 42869: val_loss did not improve from 0.11136
#
# Epoch 42870: val_loss did not improve from 0.11136
#
# Epoch 42871: val_loss did not improve from 0.11136
#
# Epoch 42872: val_loss did not improve from 0.11136
#
# Epoch 42873: val_loss did not improve from 0.11136
#
# Epoch 42874: val_loss did not improve from 0.11136
#
# Epoch 42875: val_loss did not improve from 0.11136
#
# Epoch 42876: val_loss did not improve from 0.11136
#
# Epoch 42877: val_loss did not improve from 0.11136
#
# Epoch 42878: val_loss did not improve from 0.11136
#
# Epoch 42879: val_loss did not improve from 0.11136
#
# Epoch 42880: val_loss did not improve from 0.11136
#
# Epoch 42881: val_loss did not improve from 0.11136
#
# Epoch 42882: val_loss did not improve from 0.11136
#
# Epoch 42883: val_loss did not improve from 0.11136
#
# Epoch 42884: val_loss did not improve from 0.11136
#
# Epoch 42885: val_loss did not improve from 0.11136
#
# Epoch 42886: val_loss did not improve from 0.11136
#
# Epoch 42887: val_loss did not improve from 0.11136
#
# Epoch 42888: val_loss did not improve from 0.11136
#
# Epoch 42889: val_loss did not improve from 0.11136
#
# Epoch 42890: val_loss did not improve from 0.11136
#
# Epoch 42891: val_loss did not improve from 0.11136
#
# Epoch 42892: val_loss did not improve from 0.11136
#
# Epoch 42893: val_loss did not improve from 0.11136
#
# Epoch 42894: val_loss did not improve from 0.11136
#
# Epoch 42895: val_loss did not improve from 0.11136
#
# Epoch 42896: val_loss did not improve from 0.11136
#
# Epoch 42897: val_loss did not improve from 0.11136
#
# Epoch 42898: val_loss did not improve from 0.11136
#
# Epoch 42899: val_loss did not improve from 0.11136
#
# Epoch 42900: val_loss did not improve from 0.11136
#
# Epoch 42901: val_loss did not improve from 0.11136
#
# Epoch 42902: val_loss did not improve from 0.11136
#
# Epoch 42903: val_loss did not improve from 0.11136
#
# Epoch 42904: val_loss did not improve from 0.11136
#
# Epoch 42905: val_loss did not improve from 0.11136
#
# Epoch 42906: val_loss did not improve from 0.11136
#
# Epoch 42907: val_loss did not improve from 0.11136
#
# Epoch 42908: val_loss did not improve from 0.11136
#
# Epoch 42909: val_loss did not improve from 0.11136
#
# Epoch 42910: val_loss did not improve from 0.11136
#
# Epoch 42911: val_loss did not improve from 0.11136
#
# Epoch 42912: val_loss did not improve from 0.11136
#
# Epoch 42913: val_loss did not improve from 0.11136
#
# Epoch 42914: val_loss did not improve from 0.11136
#
# Epoch 42915: val_loss did not improve from 0.11136
#
# Epoch 42916: val_loss did not improve from 0.11136
#
# Epoch 42917: val_loss did not improve from 0.11136
#
# Epoch 42918: val_loss did not improve from 0.11136
#
# Epoch 42919: val_loss did not improve from 0.11136
#
# Epoch 42920: val_loss did not improve from 0.11136
#
# Epoch 42921: val_loss did not improve from 0.11136
#
# Epoch 42922: val_loss did not improve from 0.11136
#
# Epoch 42923: val_loss did not improve from 0.11136
#
# Epoch 42924: val_loss did not improve from 0.11136
#
# Epoch 42925: val_loss did not improve from 0.11136
#
# Epoch 42926: val_loss did not improve from 0.11136
#
# Epoch 42927: val_loss did not improve from 0.11136
#
# Epoch 42928: val_loss did not improve from 0.11136
#
# Epoch 42929: val_loss did not improve from 0.11136
#
# Epoch 42930: val_loss did not improve from 0.11136
#
# Epoch 42931: val_loss did not improve from 0.11136
#
# Epoch 42932: val_loss did not improve from 0.11136
#
# Epoch 42933: val_loss did not improve from 0.11136
#
# Epoch 42934: val_loss did not improve from 0.11136
#
# Epoch 42935: val_loss did not improve from 0.11136
#
# Epoch 42936: val_loss did not improve from 0.11136
#
# Epoch 42937: val_loss did not improve from 0.11136
#
# Epoch 42938: val_loss did not improve from 0.11136
#
# Epoch 42939: val_loss did not improve from 0.11136
#
# Epoch 42940: val_loss did not improve from 0.11136
#
# Epoch 42941: val_loss did not improve from 0.11136
#
# Epoch 42942: val_loss did not improve from 0.11136
#
# Epoch 42943: val_loss did not improve from 0.11136
#
# Epoch 42944: val_loss did not improve from 0.11136
#
# Epoch 42945: val_loss did not improve from 0.11136
#
# Epoch 42946: val_loss did not improve from 0.11136
#
# Epoch 42947: val_loss did not improve from 0.11136
#
# Epoch 42948: val_loss did not improve from 0.11136
#
# Epoch 42949: val_loss did not improve from 0.11136
#
# Epoch 42950: val_loss did not improve from 0.11136
#
# Epoch 42951: val_loss did not improve from 0.11136
#
# Epoch 42952: val_loss did not improve from 0.11136
#
# Epoch 42953: val_loss did not improve from 0.11136
#
# Epoch 42954: val_loss did not improve from 0.11136
#
# Epoch 42955: val_loss did not improve from 0.11136
#
# Epoch 42956: val_loss did not improve from 0.11136
#
# Epoch 42957: val_loss did not improve from 0.11136
#
# Epoch 42958: val_loss did not improve from 0.11136
#
# Epoch 42959: val_loss did not improve from 0.11136
#
# Epoch 42960: val_loss did not improve from 0.11136
#
# Epoch 42961: val_loss did not improve from 0.11136
#
# Epoch 42962: val_loss did not improve from 0.11136
#
# Epoch 42963: val_loss did not improve from 0.11136
#
# Epoch 42964: val_loss did not improve from 0.11136
#
# Epoch 42965: val_loss did not improve from 0.11136
#
# Epoch 42966: val_loss did not improve from 0.11136
#
# Epoch 42967: val_loss did not improve from 0.11136
#
# Epoch 42968: val_loss did not improve from 0.11136
#
# Epoch 42969: val_loss did not improve from 0.11136
#
# Epoch 42970: val_loss did not improve from 0.11136
#
# Epoch 42971: val_loss did not improve from 0.11136
#
# Epoch 42972: val_loss did not improve from 0.11136
#
# Epoch 42973: val_loss did not improve from 0.11136
#
# Epoch 42974: val_loss did not improve from 0.11136
#
# Epoch 42975: val_loss did not improve from 0.11136
#
# Epoch 42976: val_loss did not improve from 0.11136
#
# Epoch 42977: val_loss did not improve from 0.11136
#
# Epoch 42978: val_loss did not improve from 0.11136
#
# Epoch 42979: val_loss did not improve from 0.11136
#
# Epoch 42980: val_loss did not improve from 0.11136
#
# Epoch 42981: val_loss did not improve from 0.11136
#
# Epoch 42982: val_loss did not improve from 0.11136
#
# Epoch 42983: val_loss did not improve from 0.11136
#
# Epoch 42984: val_loss did not improve from 0.11136
#
# Epoch 42985: val_loss did not improve from 0.11136
# Epoch 42986: val_loss did not improve from 0.11136
#
# Epoch 42987: val_loss did not improve from 0.11136
#
# Epoch 42988: val_loss did not improve from 0.11136
#
# Epoch 42989: val_loss did not improve from 0.11136
#
# Epoch 42990: val_loss did not improve from 0.11136
#
# Epoch 42991: val_loss did not improve from 0.11136
#
# Epoch 42992: val_loss did not improve from 0.11136
#
# Epoch 42993: val_loss did not improve from 0.11136
#
# Epoch 42994: val_loss did not improve from 0.11136
#
# Epoch 42995: val_loss did not improve from 0.11136
#
# Epoch 42996: val_loss did not improve from 0.11136
#
# Epoch 42997: val_loss did not improve from 0.11136
#
# Epoch 42998: val_loss did not improve from 0.11136
#
# Epoch 42999: val_loss did not improve from 0.11136
#
# Epoch 43000: val_loss did not improve from 0.11136
#
# Epoch 43001: val_loss did not improve from 0.11136
#
# Epoch 43002: val_loss did not improve from 0.11136
#
# Epoch 43003: val_loss did not improve from 0.11136
#
# Epoch 43004: val_loss did not improve from 0.11136
#
# Epoch 43005: val_loss did not improve from 0.11136
#
# Epoch 43006: val_loss did not improve from 0.11136
#
# Epoch 43007: val_loss did not improve from 0.11136
#
# Epoch 43008: val_loss did not improve from 0.11136
#
# Epoch 43009: val_loss did not improve from 0.11136
#
# Epoch 43010: val_loss did not improve from 0.11136
#
# Epoch 43011: val_loss did not improve from 0.11136
#
# Epoch 43012: val_loss did not improve from 0.11136
#
# Epoch 43013: val_loss did not improve from 0.11136
#
# Epoch 43014: val_loss did not improve from 0.11136
#
# Epoch 43015: val_loss did not improve from 0.11136
#
# Epoch 43016: val_loss did not improve from 0.11136
#
# Epoch 43017: val_loss did not improve from 0.11136
#
# Epoch 43018: val_loss did not improve from 0.11136
#
# Epoch 43019: val_loss did not improve from 0.11136
#
# Epoch 43020: val_loss did not improve from 0.11136
#
# Epoch 43021: val_loss did not improve from 0.11136
#
# Epoch 43022: val_loss did not improve from 0.11136
#
# Epoch 43023: val_loss did not improve from 0.11136
#
# Epoch 43024: val_loss did not improve from 0.11136
#
# Epoch 43025: val_loss did not improve from 0.11136
#
# Epoch 43026: val_loss did not improve from 0.11136
#
# Epoch 43027: val_loss did not improve from 0.11136
#
# Epoch 43028: val_loss did not improve from 0.11136
#
# Epoch 43029: val_loss did not improve from 0.11136
#
# Epoch 43030: val_loss did not improve from 0.11136
#
# Epoch 43031: val_loss did not improve from 0.11136
#
# Epoch 43032: val_loss did not improve from 0.11136
#
# Epoch 43033: val_loss did not improve from 0.11136
#
# Epoch 43034: val_loss did not improve from 0.11136
#
# Epoch 43035: val_loss did not improve from 0.11136
#
# Epoch 43036: val_loss did not improve from 0.11136
#
# Epoch 43037: val_loss did not improve from 0.11136
#
# Epoch 43038: val_loss did not improve from 0.11136
#
# Epoch 43039: val_loss did not improve from 0.11136
#
# Epoch 43040: val_loss did not improve from 0.11136
#
# Epoch 43041: val_loss did not improve from 0.11136
#
# Epoch 43042: val_loss did not improve from 0.11136
#
# Epoch 43043: val_loss did not improve from 0.11136
#
# Epoch 43044: val_loss did not improve from 0.11136
#
# Epoch 43045: val_loss did not improve from 0.11136
#
# Epoch 43046: val_loss did not improve from 0.11136
#
# Epoch 43047: val_loss did not improve from 0.11136
#
# Epoch 43048: val_loss did not improve from 0.11136
#
# Epoch 43049: val_loss did not improve from 0.11136
#
# Epoch 43050: val_loss did not improve from 0.11136
#
# Epoch 43051: val_loss did not improve from 0.11136
#
# Epoch 43052: val_loss did not improve from 0.11136
#
# Epoch 43053: val_loss did not improve from 0.11136
#
# Epoch 43054: val_loss did not improve from 0.11136
#
# Epoch 43055: val_loss did not improve from 0.11136
#
# Epoch 43056: val_loss did not improve from 0.11136
#
# Epoch 43057: val_loss did not improve from 0.11136
#
# Epoch 43058: val_loss did not improve from 0.11136
#
# Epoch 43059: val_loss did not improve from 0.11136
#
# Epoch 43060: val_loss did not improve from 0.11136
#
# Epoch 43061: val_loss did not improve from 0.11136
#
# Epoch 43062: val_loss did not improve from 0.11136
#
# Epoch 43063: val_loss did not improve from 0.11136
#
# Epoch 43064: val_loss did not improve from 0.11136
#
# Epoch 43065: val_loss did not improve from 0.11136
#
# Epoch 43066: val_loss did not improve from 0.11136
#
# Epoch 43067: val_loss did not improve from 0.11136
#
# Epoch 43068: val_loss did not improve from 0.11136
#
# Epoch 43069: val_loss did not improve from 0.11136
#
# Epoch 43070: val_loss did not improve from 0.11136
#
# Epoch 43071: val_loss did not improve from 0.11136
#
# Epoch 43072: val_loss did not improve from 0.11136
#
# Epoch 43073: val_loss did not improve from 0.11136
#
# Epoch 43074: val_loss did not improve from 0.11136
#
# Epoch 43075: val_loss did not improve from 0.11136
#
# Epoch 43076: val_loss did not improve from 0.11136
#
# Epoch 43077: val_loss did not improve from 0.11136
#
# Epoch 43078: val_loss did not improve from 0.11136
#
# Epoch 43079: val_loss did not improve from 0.11136
#
# Epoch 43080: val_loss did not improve from 0.11136
#
# Epoch 43081: val_loss did not improve from 0.11136
#
# Epoch 43082: val_loss did not improve from 0.11136
#
# Epoch 43083: val_loss did not improve from 0.11136
#
# Epoch 43084: val_loss did not improve from 0.11136
#
# Epoch 43085: val_loss did not improve from 0.11136
#
# Epoch 43086: val_loss did not improve from 0.11136
#
# Epoch 43087: val_loss did not improve from 0.11136
#
# Epoch 43088: val_loss did not improve from 0.11136
#
# Epoch 43089: val_loss did not improve from 0.11136
#
# Epoch 43090: val_loss did not improve from 0.11136
#
# Epoch 43091: val_loss did not improve from 0.11136
#
# Epoch 43092: val_loss did not improve from 0.11136
#
# Epoch 43093: val_loss did not improve from 0.11136
#
# Epoch 43094: val_loss did not improve from 0.11136
#
# Epoch 43095: val_loss did not improve from 0.11136
#
# Epoch 43096: val_loss did not improve from 0.11136
#
# Epoch 43097: val_loss did not improve from 0.11136
#
# Epoch 43098: val_loss did not improve from 0.11136
#
# Epoch 43099: val_loss did not improve from 0.11136
#
# Epoch 43100: val_loss did not improve from 0.11136
#
# Epoch 43101: val_loss did not improve from 0.11136
#
# Epoch 43102: val_loss did not improve from 0.11136
#
# Epoch 43103: val_loss did not improve from 0.11136
#
# Epoch 43104: val_loss did not improve from 0.11136
#
# Epoch 43105: val_loss did not improve from 0.11136
#
# Epoch 43106: val_loss did not improve from 0.11136
#
# Epoch 43107: val_loss did not improve from 0.11136
#
# Epoch 43108: val_loss did not improve from 0.11136
#
# Epoch 43109: val_loss did not improve from 0.11136
#
# Epoch 43110: val_loss did not improve from 0.11136
#
# Epoch 43111: val_loss did not improve from 0.11136
#
# Epoch 43112: val_loss did not improve from 0.11136
#
# Epoch 43113: val_loss did not improve from 0.11136
#
# Epoch 43114: val_loss did not improve from 0.11136
#
# Epoch 43115: val_loss did not improve from 0.11136
#
# Epoch 43116: val_loss did not improve from 0.11136
#
# Epoch 43117: val_loss did not improve from 0.11136
#
# Epoch 43118: val_loss did not improve from 0.11136
#
# ...
#
# Epoch 71889: val_loss did not improve from 0.10530
#
# Epoch 71890: val_loss did not improve from 0.10530
#
# Epoch 71891: val_loss did not improve from 0.10530
#
# Epoch 71892: val_loss did not improve from 0.10530
#
# Epoch 71893: val_loss did not improve from 0.10530
#
# Epoch 71894: val_loss did not improve from 0.10530
#
# Epoch 71895: val_loss did not improve from 0.10530
#
# Epoch 71896: val_loss did not improve from 0.10530
#
# Epoch 71897: val_loss did not improve from 0.10530
# Epoch 71898: val_loss did not improve from 0.10530
#
# Epoch 71899: val_loss did not improve from 0.10530
#
# Epoch 71900: val_loss did not improve from 0.10530
#
# Epoch 71901: val_loss did not improve from 0.10530
#
# Epoch 71902: val_loss did not improve from 0.10530
#
# Epoch 71903: val_loss did not improve from 0.10530
#
# Epoch 71904: val_loss did not improve from 0.10530
#
# Epoch 71905: val_loss did not improve from 0.10530
#
# Epoch 71906: val_loss did not improve from 0.10530
#
# Epoch 71907: val_loss did not improve from 0.10530
#
# Epoch 71908: val_loss did not improve from 0.10530
#
# Epoch 71909: val_loss did not improve from 0.10530
#
# Epoch 71910: val_loss did not improve from 0.10530
#
# Epoch 71911: val_loss did not improve from 0.10530
#
# Epoch 71912: val_loss did not improve from 0.10530
#
# Epoch 71913: val_loss did not improve from 0.10530
#
# Epoch 71914: val_loss did not improve from 0.10530
#
# Epoch 71915: val_loss did not improve from 0.10530
#
# Epoch 71916: val_loss did not improve from 0.10530
#
# Epoch 71917: val_loss did not improve from 0.10530
#
# Epoch 71918: val_loss did not improve from 0.10530
#
# Epoch 71919: val_loss did not improve from 0.10530
#
# Epoch 71920: val_loss did not improve from 0.10530
#
# Epoch 71921: val_loss did not improve from 0.10530
#
# Epoch 71922: val_loss did not improve from 0.10530
#
# Epoch 71923: val_loss did not improve from 0.10530
#
# Epoch 71924: val_loss did not improve from 0.10530
#
# Epoch 71925: val_loss did not improve from 0.10530
#
# Epoch 71926: val_loss did not improve from 0.10530
#
# Epoch 71927: val_loss did not improve from 0.10530
#
# Epoch 71928: val_loss did not improve from 0.10530
#
# Epoch 71929: val_loss did not improve from 0.10530
#
# Epoch 71930: val_loss did not improve from 0.10530
#
# Epoch 71931: val_loss did not improve from 0.10530
#
# Epoch 71932: val_loss did not improve from 0.10530
#
# Epoch 71933: val_loss did not improve from 0.10530
#
# Epoch 71934: val_loss did not improve from 0.10530
#
# Epoch 71935: val_loss did not improve from 0.10530
#
# Epoch 71936: val_loss did not improve from 0.10530
#
# Epoch 71937: val_loss did not improve from 0.10530
#
# Epoch 71938: val_loss did not improve from 0.10530
#
# Epoch 71939: val_loss did not improve from 0.10530
#
# Epoch 71940: val_loss did not improve from 0.10530
#
# Epoch 71941: val_loss did not improve from 0.10530
#
# Epoch 71942: val_loss did not improve from 0.10530
#
# Epoch 71943: val_loss did not improve from 0.10530
#
# Epoch 71944: val_loss did not improve from 0.10530
#
# Epoch 71945: val_loss did not improve from 0.10530
#
# Epoch 71946: val_loss did not improve from 0.10530
#
# Epoch 71947: val_loss did not improve from 0.10530
#
# Epoch 71948: val_loss did not improve from 0.10530
#
# Epoch 71949: val_loss did not improve from 0.10530
#
# Epoch 71950: val_loss did not improve from 0.10530
#
# Epoch 71951: val_loss did not improve from 0.10530
#
# Epoch 71952: val_loss did not improve from 0.10530
#
# Epoch 71953: val_loss did not improve from 0.10530
#
# Epoch 71954: val_loss did not improve from 0.10530
#
# Epoch 71955: val_loss did not improve from 0.10530
#
# Epoch 71956: val_loss did not improve from 0.10530
#
# Epoch 71957: val_loss did not improve from 0.10530
#
# Epoch 71958: val_loss did not improve from 0.10530
#
# Epoch 71959: val_loss did not improve from 0.10530
#
# Epoch 71960: val_loss did not improve from 0.10530
#
# Epoch 71961: val_loss did not improve from 0.10530
#
# Epoch 71962: val_loss did not improve from 0.10530
#
# Epoch 71963: val_loss did not improve from 0.10530
#
# Epoch 71964: val_loss did not improve from 0.10530
#
# Epoch 71965: val_loss did not improve from 0.10530
#
# Epoch 71966: val_loss did not improve from 0.10530
#
# Epoch 71967: val_loss did not improve from 0.10530
#
# Epoch 71968: val_loss did not improve from 0.10530
#
# Epoch 71969: val_loss did not improve from 0.10530
#
# Epoch 71970: val_loss did not improve from 0.10530
#
# Epoch 71971: val_loss did not improve from 0.10530
#
# Epoch 71972: val_loss did not improve from 0.10530
#
# Epoch 71973: val_loss did not improve from 0.10530
#
# Epoch 71974: val_loss did not improve from 0.10530
#
# Epoch 71975: val_loss did not improve from 0.10530
#
# Epoch 71976: val_loss did not improve from 0.10530
#
# Epoch 71977: val_loss did not improve from 0.10530
#
# Epoch 71978: val_loss did not improve from 0.10530
#
# Epoch 71979: val_loss did not improve from 0.10530
#
# Epoch 71980: val_loss did not improve from 0.10530
#
# Epoch 71981: val_loss did not improve from 0.10530
#
# Epoch 71982: val_loss did not improve from 0.10530
#
# Epoch 71983: val_loss did not improve from 0.10530
#
# Epoch 71984: val_loss did not improve from 0.10530
#
# Epoch 71985: val_loss did not improve from 0.10530
#
# Epoch 71986: val_loss did not improve from 0.10530
#
# Epoch 71987: val_loss did not improve from 0.10530
#
# Epoch 71988: val_loss did not improve from 0.10530
#
# Epoch 71989: val_loss did not improve from 0.10530
#
# Epoch 71990: val_loss did not improve from 0.10530
#
# Epoch 71991: val_loss did not improve from 0.10530
#
# Epoch 71992: val_loss did not improve from 0.10530
#
# Epoch 71993: val_loss did not improve from 0.10530
#
# Epoch 71994: val_loss did not improve from 0.10530
#
# Epoch 71995: val_loss did not improve from 0.10530
#
# Epoch 71996: val_loss did not improve from 0.10530
#
# Epoch 71997: val_loss did not improve from 0.10530
#
# Epoch 71998: val_loss did not improve from 0.10530
#
# Epoch 71999: val_loss did not improve from 0.10530
#
# Epoch 72000: val_loss did not improve from 0.10530
#
# Epoch 72001: val_loss did not improve from 0.10530
#
# Epoch 72002: val_loss did not improve from 0.10530
#
# Epoch 72003: val_loss did not improve from 0.10530
#
# Epoch 72004: val_loss did not improve from 0.10530
#
# Epoch 72005: val_loss did not improve from 0.10530
#
# Epoch 72006: val_loss did not improve from 0.10530
#
# Epoch 72007: val_loss did not improve from 0.10530
#
# Epoch 72008: val_loss did not improve from 0.10530
#
# Epoch 72009: val_loss did not improve from 0.10530
#
# Epoch 72010: val_loss did not improve from 0.10530
#
# Epoch 72011: val_loss did not improve from 0.10530
#
# Epoch 72012: val_loss did not improve from 0.10530
#
# Epoch 72013: val_loss did not improve from 0.10530
#
# Epoch 72014: val_loss did not improve from 0.10530
#
# Epoch 72015: val_loss did not improve from 0.10530
#
# Epoch 72016: val_loss did not improve from 0.10530
#
# Epoch 72017: val_loss did not improve from 0.10530
#
# Epoch 72018: val_loss did not improve from 0.10530
#
# Epoch 72019: val_loss did not improve from 0.10530
#
# Epoch 72020: val_loss did not improve from 0.10530
#
# Epoch 72021: val_loss did not improve from 0.10530
#
# Epoch 72022: val_loss did not improve from 0.10530
#
# Epoch 72023: val_loss did not improve from 0.10530
#
# Epoch 72024: val_loss did not improve from 0.10530
#
# Epoch 72025: val_loss did not improve from 0.10530
#
# Epoch 72026: val_loss did not improve from 0.10530
#
# Epoch 72027: val_loss did not improve from 0.10530
#
# Epoch 72028: val_loss did not improve from 0.10530
#
# Epoch 72029: val_loss did not improve from 0.10530
#
# Epoch 72030: val_loss did not improve from 0.10530
#
# Epoch 72031: val_loss did not improve from 0.10530
#
# Epoch 72032: val_loss did not improve from 0.10530
#
# Epoch 72033: val_loss did not improve from 0.10530
#
# Epoch 72034: val_loss did not improve from 0.10530
#
# Epoch 72035: val_loss did not improve from 0.10530
#
# Epoch 72036: val_loss did not improve from 0.10530
#
# Epoch 72037: val_loss did not improve from 0.10530
#
# Epoch 72038: val_loss did not improve from 0.10530
#
# Epoch 72039: val_loss did not improve from 0.10530
#
# Epoch 72040: val_loss did not improve from 0.10530
#
# Epoch 72041: val_loss did not improve from 0.10530
#
# Epoch 72042: val_loss did not improve from 0.10530
#
# Epoch 72043: val_loss did not improve from 0.10530
#
# Epoch 72044: val_loss did not improve from 0.10530
#
# Epoch 72045: val_loss did not improve from 0.10530
#
# Epoch 72046: val_loss did not improve from 0.10530
#
# Epoch 72047: val_loss did not improve from 0.10530
#
# Epoch 72048: val_loss did not improve from 0.10530
#
# Epoch 72049: val_loss did not improve from 0.10530
#
# Epoch 72050: val_loss did not improve from 0.10530
#
# Epoch 72051: val_loss did not improve from 0.10530
#
# Epoch 72052: val_loss did not improve from 0.10530
#
# Epoch 72053: val_loss did not improve from 0.10530
#
# Epoch 72054: val_loss did not improve from 0.10530
#
# Epoch 72055: val_loss did not improve from 0.10530
# Epoch 72056: val_loss did not improve from 0.10530
#
# Epoch 72057: val_loss did not improve from 0.10530
#
# Epoch 72058: val_loss did not improve from 0.10530
#
# Epoch 72059: val_loss did not improve from 0.10530
#
# Epoch 72060: val_loss did not improve from 0.10530
#
# Epoch 72061: val_loss did not improve from 0.10530
#
# Epoch 72062: val_loss did not improve from 0.10530
#
# Epoch 72063: val_loss did not improve from 0.10530
#
# Epoch 72064: val_loss did not improve from 0.10530
#
# Epoch 72065: val_loss did not improve from 0.10530
#
# Epoch 72066: val_loss did not improve from 0.10530
#
# Epoch 72067: val_loss did not improve from 0.10530
#
# Epoch 72068: val_loss did not improve from 0.10530
#
# Epoch 72069: val_loss did not improve from 0.10530
#
# Epoch 72070: val_loss did not improve from 0.10530
#
# Epoch 72071: val_loss did not improve from 0.10530
#
# Epoch 72072: val_loss did not improve from 0.10530
#
# Epoch 72073: val_loss did not improve from 0.10530
#
# Epoch 72074: val_loss did not improve from 0.10530
#
# Epoch 72075: val_loss did not improve from 0.10530
#
# Epoch 72076: val_loss did not improve from 0.10530
#
# Epoch 72077: val_loss did not improve from 0.10530
#
# Epoch 72078: val_loss did not improve from 0.10530
#
# Epoch 72079: val_loss did not improve from 0.10530
#
# Epoch 72080: val_loss did not improve from 0.10530
#
# Epoch 72081: val_loss did not improve from 0.10530
#
# Epoch 72082: val_loss did not improve from 0.10530
#
# Epoch 72083: val_loss did not improve from 0.10530
#
# Epoch 72084: val_loss did not improve from 0.10530
#
# Epoch 72085: val_loss did not improve from 0.10530
#
# Epoch 72086: val_loss did not improve from 0.10530
#
# Epoch 72087: val_loss did not improve from 0.10530
#
# Epoch 72088: val_loss did not improve from 0.10530
#
# Epoch 72089: val_loss did not improve from 0.10530
#
# Epoch 72090: val_loss did not improve from 0.10530
#
# Epoch 72091: val_loss did not improve from 0.10530
#
# Epoch 72092: val_loss did not improve from 0.10530
#
# Epoch 72093: val_loss did not improve from 0.10530
#
# Epoch 72094: val_loss did not improve from 0.10530
#
# Epoch 72095: val_loss did not improve from 0.10530
#
# Epoch 72096: val_loss did not improve from 0.10530
#
# Epoch 72097: val_loss did not improve from 0.10530
#
# Epoch 72098: val_loss did not improve from 0.10530
#
# Epoch 72099: val_loss did not improve from 0.10530
#
# Epoch 72100: val_loss did not improve from 0.10530
#
# Epoch 72101: val_loss did not improve from 0.10530
#
# Epoch 72102: val_loss did not improve from 0.10530
#
# Epoch 72103: val_loss did not improve from 0.10530
#
# Epoch 72104: val_loss did not improve from 0.10530
#
# Epoch 72105: val_loss did not improve from 0.10530
#
# Epoch 72106: val_loss did not improve from 0.10530
#
# Epoch 72107: val_loss did not improve from 0.10530
#
# Epoch 72108: val_loss did not improve from 0.10530
#
# Epoch 72109: val_loss did not improve from 0.10530
#
# Epoch 72110: val_loss did not improve from 0.10530
#
# Epoch 72111: val_loss did not improve from 0.10530
#
# Epoch 72112: val_loss did not improve from 0.10530
#
# Epoch 72113: val_loss did not improve from 0.10530
#
# Epoch 72114: val_loss did not improve from 0.10530
#
# Epoch 72115: val_loss did not improve from 0.10530
#
# Epoch 72116: val_loss did not improve from 0.10530
#
# Epoch 72117: val_loss did not improve from 0.10530
#
# Epoch 72118: val_loss did not improve from 0.10530
#
# Epoch 72119: val_loss did not improve from 0.10530
#
# Epoch 72120: val_loss did not improve from 0.10530
#
# Epoch 72121: val_loss did not improve from 0.10530
#
# Epoch 72122: val_loss did not improve from 0.10530
#
# Epoch 72123: val_loss did not improve from 0.10530
#
# Epoch 72124: val_loss did not improve from 0.10530
#
# Epoch 72125: val_loss did not improve from 0.10530
#
# Epoch 72126: val_loss did not improve from 0.10530
#
# Epoch 72127: val_loss did not improve from 0.10530
#
# Epoch 72128: val_loss did not improve from 0.10530
#
# Epoch 72129: val_loss did not improve from 0.10530
#
# Epoch 72130: val_loss did not improve from 0.10530
#
# Epoch 72131: val_loss did not improve from 0.10530
#
# Epoch 72132: val_loss did not improve from 0.10530
#
# Epoch 72133: val_loss did not improve from 0.10530
#
# Epoch 72134: val_loss did not improve from 0.10530
#
# Epoch 72135: val_loss did not improve from 0.10530
#
# Epoch 72136: val_loss did not improve from 0.10530
#
# Epoch 72137: val_loss did not improve from 0.10530
#
# Epoch 72138: val_loss did not improve from 0.10530
#
# Epoch 72139: val_loss did not improve from 0.10530
#
# Epoch 72140: val_loss did not improve from 0.10530
#
# Epoch 72141: val_loss did not improve from 0.10530
#
# Epoch 72142: val_loss did not improve from 0.10530
#
# Epoch 72143: val_loss did not improve from 0.10530
#
# Epoch 72144: val_loss did not improve from 0.10530
#
# Epoch 72145: val_loss did not improve from 0.10530
#
# Epoch 72146: val_loss did not improve from 0.10530
#
# Epoch 72147: val_loss did not improve from 0.10530
#
# Epoch 72148: val_loss did not improve from 0.10530
#
# Epoch 72149: val_loss did not improve from 0.10530
#
# Epoch 72150: val_loss did not improve from 0.10530
#
# Epoch 72151: val_loss did not improve from 0.10530
#
# Epoch 72152: val_loss did not improve from 0.10530
#
# Epoch 72153: val_loss did not improve from 0.10530
#
# Epoch 72154: val_loss did not improve from 0.10530
#
# Epoch 72155: val_loss did not improve from 0.10530
#
# Epoch 72156: val_loss did not improve from 0.10530
#
# Epoch 72157: val_loss did not improve from 0.10530
#
# Epoch 72158: val_loss did not improve from 0.10530
#
# Epoch 72159: val_loss did not improve from 0.10530
#
# Epoch 72160: val_loss did not improve from 0.10530
#
# Epoch 72161: val_loss did not improve from 0.10530
#
# Epoch 72162: val_loss did not improve from 0.10530
#
# Epoch 72163: val_loss did not improve from 0.10530
#
# Epoch 72164: val_loss did not improve from 0.10530
#
# Epoch 72165: val_loss did not improve from 0.10530
#
# Epoch 72166: val_loss did not improve from 0.10530
#
# Epoch 72167: val_loss did not improve from 0.10530
#
# Epoch 72168: val_loss did not improve from 0.10530
#
# Epoch 72169: val_loss did not improve from 0.10530
#
# Epoch 72170: val_loss did not improve from 0.10530
#
# Epoch 72171: val_loss did not improve from 0.10530
#
# Epoch 72172: val_loss did not improve from 0.10530
#
# Epoch 72173: val_loss did not improve from 0.10530
#
# Epoch 72174: val_loss did not improve from 0.10530
#
# Epoch 72175: val_loss did not improve from 0.10530
#
# Epoch 72176: val_loss did not improve from 0.10530
#
# Epoch 72177: val_loss did not improve from 0.10530
#
# Epoch 72178: val_loss did not improve from 0.10530
#
# Epoch 72179: val_loss did not improve from 0.10530
#
# Epoch 72180: val_loss did not improve from 0.10530
#
# Epoch 72181: val_loss did not improve from 0.10530
#
# Epoch 72182: val_loss did not improve from 0.10530
#
# Epoch 72183: val_loss did not improve from 0.10530
#
# Epoch 72184: val_loss did not improve from 0.10530
#
# Epoch 72185: val_loss did not improve from 0.10530
#
# Epoch 72186: val_loss did not improve from 0.10530
#
# Epoch 72187: val_loss did not improve from 0.10530
#
# Epoch 72188: val_loss did not improve from 0.10530
#
# Epoch 72189: val_loss did not improve from 0.10530
#
# Epoch 72190: val_loss did not improve from 0.10530
#
# Epoch 72191: val_loss did not improve from 0.10530
#
# Epoch 72192: val_loss did not improve from 0.10530
#
# Epoch 72193: val_loss did not improve from 0.10530
#
# Epoch 72194: val_loss did not improve from 0.10530
#
# Epoch 72195: val_loss did not improve from 0.10530

# %% [markdown]
# # Testing

# %%
model.load_weights('training/unseen_speakers/results/weights_lfw-crop-ctc_classification-v3.hdf5')
model.input[0]
# Out:
# <tf.Tensor 'the_input:0' shape=(?, 30, 100, 50, 3) dtype=float32>

# %%
from keras.models import Model, Sequential

# %%
prediction_model = Model(inputs = model.input[0], outputs = [model.get_layer('softmax').output,model.get_layer('classification').output])

# %%
SVG(model_to_dot(prediction_model, show_layer_names=True, show_shapes=True).create(prog='dot', format='svg'))

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import itertools


def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=False):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(11, 11))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
g_test=datagen(data_partition='test',batch_size=16)
ctc_test = []
cls_test = []
true_data = []
for i in range(128):
    print(i/128, end='\r')
    x,y=next(g_test)
    for i in range(0,16):
        X = x['the_input'][i]
    #     print(X)
        y_true = x['source_str'][i]#words[np.argmax(y[0][i])]
#         print(y_true)
    #     print(Y)append(x['source_str'])
        ctc_preds, cls_preds = prediction_model.predict(np.expand_dims(X,0))
        cls = words[np.argmax(cls_preds)]
        decoded = K.ctc_decode(y_pred=ctc_preds, input_length=(30,) ,greedy=True, beam_width=50, top_paths=50)
        paths = [path.eval(session=K.get_session()) for path in decoded[0]]
        logprobs  = decoded[1].eval(session=K.get_session())
        preds = []
        for path in paths:
            preds.append(''.join([chr(65+v) for v in path[0] ]))
        preds = np.array(preds)[0]
        ctc_test.append(preds)
        cls_test.append(cls)
        true_data.append(y_true)
# Out:
# 0.9921875

# %%
# (ctc_test,cls_test,true_data)

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl

labels = words
true_data, ctc_test, cls_test = np.array(true_data), np.array(ctc_test), np.array(cls_test)
print(true_data.shape, ctc_test.shape, cls_test.shape)
cm = confusion_matrix(true_data, ctc_test, labels)
plot_confusion_matrix(cm,words,title='Confusion Matrix ctc')
cm = confusion_matrix(true_data, cls_test, labels)
plot_confusion_matrix(cm,words,title='Confusion Matrix cls')
# Out:
# (2048,) (2048,) (2048,)
