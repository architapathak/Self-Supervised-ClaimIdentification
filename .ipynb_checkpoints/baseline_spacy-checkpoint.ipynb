# %%
import sklearn.preprocessing as preprocess
import numpy as np
import pandas as pd
from keras import backend as K
import spacy
from spacy.lang.en import English
# Out:
# Using TensorFlow backend.

# %%
df_hd_tp = pd.read_csv('evaluation_set/headline_topic_mapping.csv')
df_ar_cl = pd.read_csv('evaluation_set/article_claim_mapping.csv')
df_hd_tp.keys()
# Out:
# Index(['Topic', 'Title', 'article Id', 'Headline'], dtype='object')

# %%
hd = df_hd_tp[df_hd_tp.Title=='Video game controversies']['Headline'].values[0]
ar_id = df_hd_tp[df_hd_tp.Title=='Video game controversies']['article Id'].values[0]
cl = df_ar_cl[df_ar_cl.Article=='Video game controversies']['Claim'].values
print('ar_id:',ar_id)
print('hd:',hd)
print('cl_1:',cl[0])
# Out:
# ar_id: 1
# hd: The sale of violent video games to minors should be banned
# cl_1: exposure to violent video games causes at least a temporary increase in aggression and that this exposure correlates with aggression in the real world

# %%
with open('evaluation_set/articles/clean_{0}.txt'.format(ar_id)) as f:
    article = f.readlines()
# sentences = article.split('\n')
article=''.join(article)
# print(article)
article = article.replace('[REF]','')
nlp = English()
nlp.add_pipe(nlp.create_pipe('sentencizer')) # updated
doc = nlp(article)
sentences = [sent.string.strip() for sent in doc.sents]
len(sentences)
# Out:
# 266

# %% [markdown]
# # Load spacy vector library

# %%
nlp = spacy.load("en_core_web_md")

# %% [markdown]
# # Spacy internal sentence vector
# * get best 5 similar with headline

# %%
tokens_hd = nlp(hd)
sims = []
for i in range(len(sentences)):
    tokens_s = nlp(sentences[i])
    sims.append(tokens_hd.similarity(tokens_s))
best_count = 5
top_five = []
for idx in np.array(sims).argsort()[-best_count:][::-1]:
    top_five.append(sentences[idx])
    print(sentences[idx],'sim:',np.around(sims[idx],4))
    print('----')
# Out:
# The case centered on a California law that sought to restrict sales of violent video games to minors. sim: 0.9245
# ----
# Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children. sim: 0.9049
# ----
# The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games . sim: 0.9008
# ----
# He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game. sim: 0.899
# ----
# No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up. sim: 0.8972
# ----

# %% [markdown]
# # Similarity between Claims and Top 5

# %%
threshold = 0.95
for i in range(len(top_five)):
    t5 = nlp(top_five[i])
#     print(t5.vector)
    for j in range(len(cl)):
        _c = nlp(cl[j])
#         print(_c.vector)
        print('top_5:',t5.text)
        print('-------------------')
        print('ground_truth:',_c.text)
        print('t5:{0}, cl:{1}, sim: {2}'.format(i,j,np.around(t5.similarity(_c),4)))
        print('===================================================================')
# Out:
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: exposure to violent video games causes at least a temporary increase in aggression and that this exposure correlates with aggression in the real world
# t5:0, cl:0, sim: 0.8972
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: video game violence is not related to serious aggressive behavior in real life
# t5:0, cl:1, sim: 0.8956
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: some violent video games may actually have a prosocial effect in some contexts
# t5:0, cl:2, sim: 0.881
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: exposure to violent video games causes both short term and long term aggression in players and decreases empathy and prosocial behavior
# t5:0, cl:3, sim: 0.8536
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: they increase the violent tendencies among youth
# t5:0, cl:4, sim: 0.8123
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: have shown no conclusive link between video game usage and violent activity
# t5:0, cl:5, sim: 0.8688
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: violent video games are significantly associated with: increased aggressive behavior, thoughts, and affect; increased physiological arousal; and decreased pro-social (helping) behavior
# t5:0, cl:6, sim: 0.813
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder
# t5:0, cl:7, sim: 0.906
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: violent video games may increase mild forms of aggressive behavior in children and young adults
# t5:0, cl:8, sim: 0.8578
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: exposure to violent video games results in increased physiological arousal, aggression-related thoughts and feelings as well as decreased prosocial behavior
# t5:0, cl:9, sim: 0.8132
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: violence in video games is not causally linked with aggressive tendencies
# t5:0, cl:10, sim: 0.8535
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: no long-term relationship between playing violent video game and youth violence or bullying
# t5:0, cl:11, sim: 0.8663
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: aggressive children tend to select more violent video games, not the inverse
# t5:0, cl:12, sim: 0.8859
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: no evidence violent games are psychologically harmful to minors
# t5:0, cl:13, sim: 0.817
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: adolescents that don't play video games at all are most at-risk for violent behavior
# t5:0, cl:14, sim: 0.8662
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: video game play is part of an adolescent boy's normal social setting
# t5:0, cl:15, sim: 0.8522
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: Other biological theories of aggression and violence have specifically excluded video game and other media effects
# t5:0, cl:16, sim: 0.8601
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: Reinforcement of sexist stereotypes has also been claimed as an effect of violent video games
# t5:0, cl:17, sim: 0.8583
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: a correlation between children playing violent video games and suffering psychological effects
# t5:0, cl:18, sim: 0.8287
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: violent video games can increase children's aggression
# t5:0, cl:19, sim: 0.8416
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: media influences are too weak and distant to have much influence
# t5:0, cl:20, sim: 0.8021
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: violent video games promote violent behavior, attitudes and beliefs by desensitizing an individual to aggression
# t5:0, cl:21, sim: 0.8449
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: Excessive exposure to violent video games and other violent media has been linked to aggressive behaviour
# t5:0, cl:22, sim: 0.8728
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: neurological link between playing violent video games and aggressive behaviour in children and teenagers
# t5:0, cl:23, sim: 0.8375
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: there was no direct link between violent video games and their influence on children
# t5:0, cl:24, sim: 0.9024
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: Video games also develop the individual's intelligence
# t5:0, cl:25, sim: 0.8441
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: violent games help students deal with stress and aggression
# t5:0, cl:26, sim: 0.8276
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: violent games affect students positively and not negatively
# t5:0, cl:27, sim: 0.825
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: many skills can be learned from the gaming experience, it builds practical and intellectual skills
# t5:0, cl:28, sim: 0.8184
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: media cannot cause violence because humans have the ability to recognize what is wrong, and what is right
# t5:0, cl:29, sim: 0.8619
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: video games have many healthy and positive aspects
# t5:0, cl:30, sim: 0.8251
# ====================================================================
# top_5: The case centered on a California law that sought to restrict sales of violent video games to minors.
# -------------------
# ground_truth: they can be a safe outlet for aggression and frustration
# t5:0, cl:31, sim: 0.8374
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: exposure to violent video games causes at least a temporary increase in aggression and that this exposure correlates with aggression in the real world
# t5:1, cl:0, sim: 0.8792
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: video game violence is not related to serious aggressive behavior in real life
# t5:1, cl:1, sim: 0.8865
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: some violent video games may actually have a prosocial effect in some contexts
# t5:1, cl:2, sim: 0.9006
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: exposure to violent video games causes both short term and long term aggression in players and decreases empathy and prosocial behavior
# t5:1, cl:3, sim: 0.8497
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: they increase the violent tendencies among youth
# t5:1, cl:4, sim: 0.8196
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: have shown no conclusive link between video game usage and violent activity
# t5:1, cl:5, sim: 0.8723
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: violent video games are significantly associated with: increased aggressive behavior, thoughts, and affect; increased physiological arousal; and decreased pro-social (helping) behavior
# t5:1, cl:6, sim: 0.8166
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder
# t5:1, cl:7, sim: 0.9125
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: violent video games may increase mild forms of aggressive behavior in children and young adults
# t5:1, cl:8, sim: 0.8671
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: exposure to violent video games results in increased physiological arousal, aggression-related thoughts and feelings as well as decreased prosocial behavior
# t5:1, cl:9, sim: 0.8228
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: violence in video games is not causally linked with aggressive tendencies
# t5:1, cl:10, sim: 0.8559
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: no long-term relationship between playing violent video game and youth violence or bullying
# t5:1, cl:11, sim: 0.8563
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: aggressive children tend to select more violent video games, not the inverse
# t5:1, cl:12, sim: 0.9158
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: no evidence violent games are psychologically harmful to minors
# t5:1, cl:13, sim: 0.8403
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: adolescents that don't play video games at all are most at-risk for violent behavior
# t5:1, cl:14, sim: 0.9409
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: video game play is part of an adolescent boy's normal social setting
# t5:1, cl:15, sim: 0.8659
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: Other biological theories of aggression and violence have specifically excluded video game and other media effects
# t5:1, cl:16, sim: 0.8554
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: Reinforcement of sexist stereotypes has also been claimed as an effect of violent video games
# t5:1, cl:17, sim: 0.8641
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: a correlation between children playing violent video games and suffering psychological effects
# t5:1, cl:18, sim: 0.8338
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: violent video games can increase children's aggression
# t5:1, cl:19, sim: 0.8555
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: media influences are too weak and distant to have much influence
# t5:1, cl:20, sim: 0.8581
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: violent video games promote violent behavior, attitudes and beliefs by desensitizing an individual to aggression
# t5:1, cl:21, sim: 0.8282
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: Excessive exposure to violent video games and other violent media has been linked to aggressive behaviour
# t5:1, cl:22, sim: 0.8729
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: neurological link between playing violent video games and aggressive behaviour in children and teenagers
# t5:1, cl:23, sim: 0.8553
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: there was no direct link between violent video games and their influence on children
# t5:1, cl:24, sim: 0.9131
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: Video games also develop the individual's intelligence
# t5:1, cl:25, sim: 0.8614
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: violent games help students deal with stress and aggression
# t5:1, cl:26, sim: 0.8402
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: violent games affect students positively and not negatively
# t5:1, cl:27, sim: 0.8562
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: many skills can be learned from the gaming experience, it builds practical and intellectual skills
# t5:1, cl:28, sim: 0.846
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: media cannot cause violence because humans have the ability to recognize what is wrong, and what is right
# t5:1, cl:29, sim: 0.9085
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: video games have many healthy and positive aspects
# t5:1, cl:30, sim: 0.8807
# ====================================================================
# top_5: Certain game publishers’ decision to have controversial games rated seems to show that they are not targeted at young children.
# -------------------
# ground_truth: they can be a safe outlet for aggression and frustration
# t5:1, cl:31, sim: 0.8641
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: exposure to violent video games causes at least a temporary increase in aggression and that this exposure correlates with aggression in the real world
# t5:2, cl:0, sim: 0.913
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: video game violence is not related to serious aggressive behavior in real life
# t5:2, cl:1, sim: 0.8966
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: some violent video games may actually have a prosocial effect in some contexts
# t5:2, cl:2, sim: 0.9082
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: exposure to violent video games causes both short term and long term aggression in players and decreases empathy and prosocial behavior
# t5:2, cl:3, sim: 0.8776
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: they increase the violent tendencies among youth
# t5:2, cl:4, sim: 0.8265
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: have shown no conclusive link between video game usage and violent activity
# t5:2, cl:5, sim: 0.8962
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: violent video games are significantly associated with: increased aggressive behavior, thoughts, and affect; increased physiological arousal; and decreased pro-social (helping) behavior
# t5:2, cl:6, sim: 0.8468
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder
# t5:2, cl:7, sim: 0.9162
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: violent video games may increase mild forms of aggressive behavior in children and young adults
# t5:2, cl:8, sim: 0.8953
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: exposure to violent video games results in increased physiological arousal, aggression-related thoughts and feelings as well as decreased prosocial behavior
# t5:2, cl:9, sim: 0.8441
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: violence in video games is not causally linked with aggressive tendencies
# t5:2, cl:10, sim: 0.8697
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: no long-term relationship between playing violent video game and youth violence or bullying
# t5:2, cl:11, sim: 0.8721
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: aggressive children tend to select more violent video games, not the inverse
# t5:2, cl:12, sim: 0.9223
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: no evidence violent games are psychologically harmful to minors
# t5:2, cl:13, sim: 0.7981
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: adolescents that don't play video games at all are most at-risk for violent behavior
# t5:2, cl:14, sim: 0.9312
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: video game play is part of an adolescent boy's normal social setting
# t5:2, cl:15, sim: 0.8969
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: Other biological theories of aggression and violence have specifically excluded video game and other media effects
# t5:2, cl:16, sim: 0.8891
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: Reinforcement of sexist stereotypes has also been claimed as an effect of violent video games
# t5:2, cl:17, sim: 0.8909
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: a correlation between children playing violent video games and suffering psychological effects
# t5:2, cl:18, sim: 0.8714
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: violent video games can increase children's aggression
# t5:2, cl:19, sim: 0.8723
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: media influences are too weak and distant to have much influence
# t5:2, cl:20, sim: 0.8615
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: violent video games promote violent behavior, attitudes and beliefs by desensitizing an individual to aggression
# t5:2, cl:21, sim: 0.8392
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: Excessive exposure to violent video games and other violent media has been linked to aggressive behaviour
# t5:2, cl:22, sim: 0.8832
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: neurological link between playing violent video games and aggressive behaviour in children and teenagers
# t5:2, cl:23, sim: 0.8812
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: there was no direct link between violent video games and their influence on children
# t5:2, cl:24, sim: 0.9289
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: Video games also develop the individual's intelligence
# t5:2, cl:25, sim: 0.8905
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: violent games help students deal with stress and aggression
# t5:2, cl:26, sim: 0.8354
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: violent games affect students positively and not negatively
# t5:2, cl:27, sim: 0.8373
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: many skills can be learned from the gaming experience, it builds practical and intellectual skills
# t5:2, cl:28, sim: 0.8624
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: media cannot cause violence because humans have the ability to recognize what is wrong, and what is right
# t5:2, cl:29, sim: 0.9007
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: video games have many healthy and positive aspects
# t5:2, cl:30, sim: 0.9014
# ====================================================================
# top_5: The adult demographic is the fastest-growing segment of the American video games market with 32% of adults playing video games, although critics have suggested that such statistics are often used to deflect from the fact that almost all American children are exposed to video games .
# -------------------
# ground_truth: they can be a safe outlet for aggression and frustration
# t5:2, cl:31, sim: 0.8552
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: exposure to violent video games causes at least a temporary increase in aggression and that this exposure correlates with aggression in the real world
# t5:3, cl:0, sim: 0.9223
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: video game violence is not related to serious aggressive behavior in real life
# t5:3, cl:1, sim: 0.9044
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: some violent video games may actually have a prosocial effect in some contexts
# t5:3, cl:2, sim: 0.9054
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: exposure to violent video games causes both short term and long term aggression in players and decreases empathy and prosocial behavior
# t5:3, cl:3, sim: 0.8804
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: they increase the violent tendencies among youth
# t5:3, cl:4, sim: 0.8323
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: have shown no conclusive link between video game usage and violent activity
# t5:3, cl:5, sim: 0.8784
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: violent video games are significantly associated with: increased aggressive behavior, thoughts, and affect; increased physiological arousal; and decreased pro-social (helping) behavior
# t5:3, cl:6, sim: 0.834
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder
# t5:3, cl:7, sim: 0.9793
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: violent video games may increase mild forms of aggressive behavior in children and young adults
# t5:3, cl:8, sim: 0.8751
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: exposure to violent video games results in increased physiological arousal, aggression-related thoughts and feelings as well as decreased prosocial behavior
# t5:3, cl:9, sim: 0.8426
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: violence in video games is not causally linked with aggressive tendencies
# t5:3, cl:10, sim: 0.863
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: no long-term relationship between playing violent video game and youth violence or bullying
# t5:3, cl:11, sim: 0.8771
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: aggressive children tend to select more violent video games, not the inverse
# t5:3, cl:12, sim: 0.9061
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: no evidence violent games are psychologically harmful to minors
# t5:3, cl:13, sim: 0.8195
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: adolescents that don't play video games at all are most at-risk for violent behavior
# t5:3, cl:14, sim: 0.9017
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: video game play is part of an adolescent boy's normal social setting
# t5:3, cl:15, sim: 0.8857
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: Other biological theories of aggression and violence have specifically excluded video game and other media effects
# t5:3, cl:16, sim: 0.8899
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: Reinforcement of sexist stereotypes has also been claimed as an effect of violent video games
# t5:3, cl:17, sim: 0.888
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: a correlation between children playing violent video games and suffering psychological effects
# t5:3, cl:18, sim: 0.8635
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: violent video games can increase children's aggression
# t5:3, cl:19, sim: 0.8629
# ====================================================================
# ...
# -------------------
# ground_truth: violent games affect students positively and not negatively
# t5:3, cl:27, sim: 0.8333
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: many skills can be learned from the gaming experience, it builds practical and intellectual skills
# t5:3, cl:28, sim: 0.8761
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: media cannot cause violence because humans have the ability to recognize what is wrong, and what is right
# t5:3, cl:29, sim: 0.9113
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: video games have many healthy and positive aspects
# t5:3, cl:30, sim: 0.8564
# ====================================================================
# top_5: He argues that video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder by simulating the killing of hundreds or thousands of opponents in a single typical video game.
# -------------------
# ground_truth: they can be a safe outlet for aggression and frustration
# t5:3, cl:31, sim: 0.8719
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: exposure to violent video games causes at least a temporary increase in aggression and that this exposure correlates with aggression in the real world
# t5:4, cl:0, sim: 0.8984
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: video game violence is not related to serious aggressive behavior in real life
# t5:4, cl:1, sim: 0.8899
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: some violent video games may actually have a prosocial effect in some contexts
# t5:4, cl:2, sim: 0.8842
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: exposure to violent video games causes both short term and long term aggression in players and decreases empathy and prosocial behavior
# t5:4, cl:3, sim: 0.8509
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: they increase the violent tendencies among youth
# t5:4, cl:4, sim: 0.7685
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: have shown no conclusive link between video game usage and violent activity
# t5:4, cl:5, sim: 0.8887
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: violent video games are significantly associated with: increased aggressive behavior, thoughts, and affect; increased physiological arousal; and decreased pro-social (helping) behavior
# t5:4, cl:6, sim: 0.8285
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: video game publishers unethically train children in the use of weapons and, more importantly, harden them emotionally to the act of murder
# t5:4, cl:7, sim: 0.9125
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: violent video games may increase mild forms of aggressive behavior in children and young adults
# t5:4, cl:8, sim: 0.8535
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: exposure to violent video games results in increased physiological arousal, aggression-related thoughts and feelings as well as decreased prosocial behavior
# t5:4, cl:9, sim: 0.8118
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: violence in video games is not causally linked with aggressive tendencies
# t5:4, cl:10, sim: 0.8452
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: no long-term relationship between playing violent video game and youth violence or bullying
# t5:4, cl:11, sim: 0.857
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: aggressive children tend to select more violent video games, not the inverse
# t5:4, cl:12, sim: 0.8994
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: no evidence violent games are psychologically harmful to minors
# t5:4, cl:13, sim: 0.7823
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: adolescents that don't play video games at all are most at-risk for violent behavior
# t5:4, cl:14, sim: 0.9112
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: video game play is part of an adolescent boy's normal social setting
# t5:4, cl:15, sim: 0.8928
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: Other biological theories of aggression and violence have specifically excluded video game and other media effects
# t5:4, cl:16, sim: 0.8457
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: Reinforcement of sexist stereotypes has also been claimed as an effect of violent video games
# t5:4, cl:17, sim: 0.8658
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: a correlation between children playing violent video games and suffering psychological effects
# t5:4, cl:18, sim: 0.8318
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: violent video games can increase children's aggression
# t5:4, cl:19, sim: 0.841
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: media influences are too weak and distant to have much influence
# t5:4, cl:20, sim: 0.8248
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: violent video games promote violent behavior, attitudes and beliefs by desensitizing an individual to aggression
# t5:4, cl:21, sim: 0.8103
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: Excessive exposure to violent video games and other violent media has been linked to aggressive behaviour
# t5:4, cl:22, sim: 0.8538
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: neurological link between playing violent video games and aggressive behaviour in children and teenagers
# t5:4, cl:23, sim: 0.8355
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: there was no direct link between violent video games and their influence on children
# t5:4, cl:24, sim: 0.9127
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: Video games also develop the individual's intelligence
# t5:4, cl:25, sim: 0.8707
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: violent games help students deal with stress and aggression
# t5:4, cl:26, sim: 0.8177
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: violent games affect students positively and not negatively
# t5:4, cl:27, sim: 0.8
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: many skills can be learned from the gaming experience, it builds practical and intellectual skills
# t5:4, cl:28, sim: 0.8593
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: media cannot cause violence because humans have the ability to recognize what is wrong, and what is right
# t5:4, cl:29, sim: 0.9034
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: video games have many healthy and positive aspects
# t5:4, cl:30, sim: 0.8604
# ====================================================================
# top_5: No video game console manufacturer has yet to allow any game to be published in North America with the harshest ESRB rating, "Adults Only", signaling that the game is only appropriate for ages 18 years and up.
# -------------------
# ground_truth: they can be a safe outlet for aggression and frustration
# t5:4, cl:31, sim: 0.8724
# ====================================================================

# %%
# def get_sent_emb(token_vectors,mode='sum'):
#     if mode == 'sum':
#         return np.sum(token_vectors)

# tokens_hd = nlp(hd)
# # hd_emb = get_sent_emb(tokens_hd.)
# sims = []
# for i in range(len(sentences)):#     print(s)
#     tokens_s = nlp(sentences[i])
# #     print('sim {0}:{1}'.format(i,tokens_hd.similarity(tokens_s)))
#     sims.append(tokens_hd.similarity(tokens_s))

    
# # tokens_s.vector
# best_count = 5
# # print(np.array(sims).argsort()[-best_count:][::-1])
# for idx in np.array(sims).argsort()[-best_count:][::-1]:
#     print(sentences[idx],'sim:',np.around(sims[idx],4))
#     print('----')

# %%
# import keras
# from keras_bert import get_base_dict, get_model, compile_model, gen_batch_inputs


# # A toy input example
# sentence_pairs = [
#     [['all', 'work', 'and', 'no', 'play'], ['makes', 'jack', 'a', 'dull', 'boy']],
#     [['from', 'the', 'day', 'forth'], ['my', 'arm', 'changed']],
#     [['and', 'a', 'voice', 'echoed'], ['power', 'give', 'me', 'more', 'power']],
# ]


# # Build token dictionary
# token_dict = get_base_dict()  # A dict that contains some special tokens
# for pairs in sentence_pairs:
#     for token in pairs[0] + pairs[1]:
#         if token not in token_dict:
#             token_dict[token] = len(token_dict)
# token_list = list(token_dict.keys())  # Used for selecting a random word

# def _custom_layers(x, trainable=True):
#     return keras.layers.LSTM(
#         units=768,
#         trainable=trainable,
#         name='LSTM',
#     )(x)


# # Build & train the model
# model = get_model(
#     token_num=len(token_dict),
#     head_num=5,
#     transformer_num=12,
#     embed_dim=25,
#     feed_forward_dim=100,
#     seq_len=20,
#     pos_num=20,
#     dropout_rate=0.05,
#     custom_layers=_custom_layers,
# )
# compile_model(model)
# model.summary()

# def _generator():
#     while True:
#         yield gen_batch_inputs(
#             sentence_pairs,
#             token_dict,
#             token_list,
#             seq_len=20,
#             mask_rate=0.3,
#             swap_sentence_rate=1.0,
#         )

# # model.fit_generator(
# #     generator=_generator(),
# #     steps_per_epoch=1000,
# #     epochs=100,
# #     validation_data=_generator(),
# #     validation_steps=100,
# #     callbacks=[
# #         keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
# #     ],
# # )


# # # Use the trained model
# # inputs, output_layer = get_model(
# #     token_num=len(token_dict),
# #     head_num=5,
# #     transformer_num=12,
# #     embed_dim=25,
# #     feed_forward_dim=100,
# #     seq_len=20,
# #     pos_num=20,
# #     dropout_rate=0.05,
# #     training=False,      # The input layers and output layer will be returned if `training` is `False`
# #     trainable=False,     # Whether the model is trainable. The default value is the same with `training`
# #     output_layer_num=4,  # The number of layers whose outputs will be concatenated as a single output.
# #                          # Only available when `training` is `False`.
# # )

# %%
# inputs

# %%
# output_layer

# %%
# next(_generator())

# %%
# np.shape(x)

# %%
# y

# %%
# token_dict

# %%
# token_list

# %%
# # Build token dictionary
# token_dict = get_base_dict()  # A dict that contains some special tokens
# for pairs in sentence_pairs:
#     for token in pairs[0] + pairs[1]:
#         if token not in token_dict:
#             token_dict[token] = len(token_dict)

# %%
# model.predict(_generator())
